# %%
from google.colab import drive #Only if you are using Google Drive
drive.mount('/content/gdrive')
drive.mount("/content/gdrive", force_remount=True)
# %cd /content/gdrive/My\ Drive/
# Out:
# Mounted at /content/gdrive
# Mounted at /content/gdrive
# /content/gdrive/My Drive

# %%
import librosa, librosa.display
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

us8kf = '/content/gdrive/MyDrive/urbansound/UrbanSound8K.csv'
mycsv = pd.read_csv(us8kf)
df_us8kf = pd.DataFrame(mycsv)

print(df_us8kf.info())
print(df_us8kf.head())

wavf = '/content/gdrive/MyDrive/urbansound/wav/fold'
figf = '/content/gdrive/MyDrive/urbansound/dataset/'
df_us8kf['wavfile']=df_us8kf.apply(lambda row: wavf+str(row.fold)+'/'+row.slice_file_name, axis=1)
df_us8kf['figfile']=df_us8kf.apply(lambda row: figf+row.slice_file_name+'.png', axis=1)
df_us8kf['split'] = 'undetermined'
print(df_us8kf.info())

df_us8kf['class'].value_counts()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8732 entries, 0 to 8731
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   slice_file_name  8732 non-null   object
#  1   fsID             8732 non-null   int64
#  2   start            8732 non-null   float64
#  3   end              8732 non-null   float64
#  4   salience         8732 non-null   int64
#  5   fold             8732 non-null   int64
#  6   classID          8732 non-null   int64
#  7   class            8732 non-null   object
# dtypes: float64(2), int64(4), object(2)
# memory usage: 545.9+ KB
# None
#       slice_file_name    fsID  start        end  salience  fold  classID  \
# 0    100032-3-0-0.wav  100032    0.0   0.317551         1     5        3
# 1  100263-2-0-117.wav  100263   58.5  62.500000         1     5        2
# 2  100263-2-0-121.wav  100263   60.5  64.500000         1     5        2
# 3  100263-2-0-126.wav  100263   63.0  67.000000         1     5        2
# 4  100263-2-0-137.wav  100263   68.5  72.500000         1     5        2
#
#               class
# 0          dog_bark
# 1  children_playing
# 2  children_playing
# 3  children_playing
# 4  children_playing
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8732 entries, 0 to 8731
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   slice_file_name  8732 non-null   object
#  1   fsID             8732 non-null   int64
#  2   start            8732 non-null   float64
#  3   end              8732 non-null   float64
#  4   salience         8732 non-null   int64
#  5   fold             8732 non-null   int64
#  6   classID          8732 non-null   int64
#  7   class            8732 non-null   object
#  8   wavfile          8732 non-null   object
#  9   figfile          8732 non-null   object
#  10  split            8732 non-null   object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 750.5+ KB
# None
# dog_bark            1000
# children_playing    1000
# air_conditioner     1000
# street_music        1000
# engine_idling       1000
# jackhammer          1000
# drilling            1000
# siren                929
# car_horn             429
# gun_shot             374
# Name: class, dtype: int64

# %%
df_1 = df_us8kf[df_us8kf['class'] == 'dog_bark'].copy()
df_2 = df_us8kf[df_us8kf['class'] == 'children_playing'].copy()
df_3 = df_us8kf[df_us8kf['class'] == 'air_conditioner'].copy()
df_4 = df_us8kf[df_us8kf['class'] == 'street_music'].copy()
df_5 = df_us8kf[df_us8kf['class'] == 'engine_idling'].copy()
df_6 = df_us8kf[df_us8kf['class'] == 'jackhammer'].copy()
df_7 = df_us8kf[df_us8kf['class'] == 'drilling'].copy()
df_8 = df_us8kf[df_us8kf['class'] == 'siren'].copy()
df_9 = df_us8kf[df_us8kf['class'] == 'car_horn'].copy()
df_10 = df_us8kf[df_us8kf['class'] == 'gun_shot'].copy()

# %%
all=[]
#df_1.shape[0]
trainct = round((df_1.shape[0])* 0.8)
rowct = 0

for row in df_1.itertuples():
    if rowct <= (trainct-1):
        df_1.at[row.Index, "split"] = 'train'
        rowct = rowct+1
    else:
        df_1.at[row.Index, 'split'] = 'test'

##################################
trainct = round((df_2.shape[0])* 0.8)
rowct = 0

for row in df_2.itertuples():
    if rowct <= (trainct-1):
        df_2.at[row.Index, "split"] = 'train'
        rowct = rowct+1
    else:
        df_2.at[row.Index, 'split'] = 'test'
##################################
trainct = round((df_3.shape[0])* 0.8)
rowct = 0

for row in df_3.itertuples():
    if rowct <= (trainct-1):
        df_3.at[row.Index, "split"] = 'train'
        rowct = rowct+1
    else:
        df_3.at[row.Index, 'split'] = 'test'
##################################
trainct = round((df_4.shape[0])* 0.8)
rowct = 0

for row in df_4.itertuples():
    if rowct <= (trainct-1):
        df_4.at[row.Index, "split"] = 'train'
        rowct = rowct+1
    else:
        df_4.at[row.Index, 'split'] = 'test'

##################################
trainct = round((df_5.shape[0])* 0.8)
rowct = 0

for row in df_5.itertuples():
    if rowct <= (trainct-1):
        df_5.at[row.Index, "split"] = 'train'
        rowct = rowct+1
    else:
        df_5.at[row.Index, 'split'] = 'test'
##################################
trainct = round((df_6.shape[0])* 0.8)
rowct = 0

for row in df_6.itertuples():
    if rowct <= (trainct-1):
        df_6.at[row.Index, "split"] = 'train'
        rowct = rowct+1
    else:
        df_6.at[row.Index, 'split'] = 'test'
##################################
trainct = round((df_7.shape[0])* 0.8)
rowct = 0

for row in df_7.itertuples():
    if rowct <= (trainct-1):
        df_7.at[row.Index, "split"] = 'train'
        rowct = rowct+1
    else:
        df_7.at[row.Index, 'split'] = 'test'
##################################
trainct = round((df_8.shape[0])* 0.8)
rowct = 0

for row in df_8.itertuples():
    if rowct <= (trainct-1):
        df_8.at[row.Index, "split"] = 'train'
        rowct = rowct+1
    else:
        df_8.at[row.Index, 'split'] = 'test'
##################################
trainct = round((df_9.shape[0])* 0.8)
rowct = 0

for row in df_9.itertuples():
    if rowct <= (trainct-1):
        df_9.at[row.Index, "split"] = 'train'
        rowct = rowct+1
    else:
        df_9.at[row.Index, 'split'] = 'test'
##################################
trainct = round((df_10.shape[0])* 0.8)
rowct = 0

for row in df_10.itertuples():
    if rowct <= (trainct-1):
        df_10.at[row.Index, "split"] = 'train'
        rowct = rowct+1
    else:
        df_10.at[row.Index, 'split'] = 'test'

frames = [df_1, df_2, df_3, df_4, df_5, df_6, df_7, df_8, df_9, df_10]
df_all = pd.concat(frames)
#result.to_csv('/Users/gracie/ML/AEA_dataset/UrbanSound8K/df_all.csv')
print(df_all.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8732 entries, 0 to 8435
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   slice_file_name  8732 non-null   object
#  1   fsID             8732 non-null   int64
#  2   start            8732 non-null   float64
#  3   end              8732 non-null   float64
#  4   salience         8732 non-null   int64
#  5   fold             8732 non-null   int64
#  6   classID          8732 non-null   int64
#  7   class            8732 non-null   object
#  8   wavfile          8732 non-null   object
#  9   figfile          8732 non-null   object
#  10  split            8732 non-null   object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 818.6+ KB
# None

# %%
# function to generate log scaled mel spectograms

srhz=44100
frame_size = int(srhz/1000*960)
frame_shift = int(srhz/1000*25)
fct = 0

for i in df_all.itertuples():
    fct = fct+1
    audiofile = i[9]
    pngfile = figf+i[11]+'/'+i[1]+'.png'
    print('FileCount = ' + str(fct) + ': Working on spectogram ' + pngfile)
    # generate spectogram
    signal, sr = librosa.load(audiofile, sr=None)
    hop_length=512
    n_fft=2048
    fmin=20
    fmax=8300
    top_db=80
    n_mels = 128
    hop_length_duration = float(hop_length)/sr
    n_fft_duration = float(n_fft)/sr
    # Mel filter banks
    filter_banks = librosa.filters.mel(n_fft=n_fft, sr=sr, n_mels=n_mels)
    stft = librosa.stft(signal, n_fft=n_fft, hop_length=hop_length)
    # This will yield 96-length spectrograms
    spectrogram = np.abs(stft)
    # converted to 64 bin log-scaled Mel spectrogram,
    melspec = librosa.feature.melspectrogram(y=signal, sr=sr, S=spectrogram,
                                             n_fft=n_fft, hop_length=hop_length,
                                             win_length=None, window='hann',
                                             center=True, pad_mode='reflect', n_mels=n_mels,
                                             fmin=fmin, fmax=fmax)
    #log_mel_spectrogram = librosa.power_to_db(melspec, ref=np.max) top_db=top_db
    log_mel_spectrogram = librosa.power_to_db(melspec, top_db=top_db)
    #plt.figure(figsize=(2.24, 2.24))
    fig = librosa.display.specshow(log_mel_spectrogram, hop_length=hop_length)
    fig2 = plt.gcf()
    plt.axis('off')
    # uncomment the line below to create 224x224 pngs
    fig2.set_size_inches(2.9, 2.98)
    #plt.imshow(cmap='gray_r')
    plt.savefig(pngfile, dpi=100, bbox_inches='tight', pad_inches=0, format='png')
# Out:
# FileCount = 1: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/100032-3-0-0.wav.png
# FileCount = 2: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/100652-3-0-0.wav.png
# FileCount = 3: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/100652-3-0-1.wav.png
# FileCount = 4: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/100652-3-0-2.wav.png
# FileCount = 5: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/100652-3-0-3.wav.png
# FileCount = 6: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/100795-3-0-0.wav.png
# FileCount = 7: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/100795-3-1-0.wav.png
# FileCount = 8: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/100795-3-1-1.wav.png
# FileCount = 9: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/100795-3-1-2.wav.png
# FileCount = 10: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/101281-3-0-0.wav.png
# FileCount = 11: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/101281-3-0-14.wav.png
# FileCount = 12: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/101281-3-0-5.wav.png
# FileCount = 13: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/101415-3-0-2.wav.png
# FileCount = 14: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/101415-3-0-3.wav.png
# FileCount = 15: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/101415-3-0-8.wav.png
# FileCount = 16: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/102102-3-0-0.wav.png
# FileCount = 17: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/102103-3-0-0.wav.png
# FileCount = 18: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/102103-3-1-0.wav.png
# FileCount = 19: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/102104-3-0-0.wav.png
# FileCount = 20: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/102105-3-0-0.wav.png
# FileCount = 21: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/102106-3-0-0.wav.png
# FileCount = 22: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/102547-3-0-2.wav.png
# FileCount = 23: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/102547-3-0-7.wav.png
# FileCount = 24: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/102547-3-0-8.wav.png
# FileCount = 25: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/102842-3-0-1.wav.png
# FileCount = 26: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/102842-3-1-0.wav.png
# FileCount = 27: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/102842-3-1-5.wav.png
# FileCount = 28: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/102842-3-1-6.wav.png
# FileCount = 29: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/103076-3-0-0.wav.png
# FileCount = 30: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/103076-3-1-0.wav.png
# FileCount = 31: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/103076-3-2-0.wav.png
# FileCount = 32: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/105088-3-0-10.wav.png
# FileCount = 33: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/105088-3-0-11.wav.png
# FileCount = 34: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/105088-3-0-19.wav.png
# FileCount = 35: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/105088-3-0-8.wav.png
# FileCount = 36: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/105319-3-0-22.wav.png
# FileCount = 37: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/105319-3-0-29.wav.png
# FileCount = 38: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/105319-3-0-39.wav.png
# FileCount = 39: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/107190-3-0-0.wav.png
# FileCount = 40: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/108187-3-2-0.wav.png
# FileCount = 41: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/108187-3-3-0.wav.png
# FileCount = 42: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/108187-3-4-0.wav.png
# FileCount = 43: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/108187-3-6-0.wav.png
# FileCount = 44: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/109233-3-0-3.wav.png
# FileCount = 45: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/109233-3-0-4.wav.png
# FileCount = 46: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/109233-3-0-5.wav.png
# FileCount = 47: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/109233-3-0-6.wav.png
# FileCount = 48: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/109711-3-1-0.wav.png
# FileCount = 49: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/109711-3-2-4.wav.png
# FileCount = 50: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/109711-3-2-6.wav.png
# FileCount = 51: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/110134-3-0-0.wav.png
# FileCount = 52: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/110371-3-0-1.wav.png
# FileCount = 53: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/110371-3-1-0.wav.png
# FileCount = 54: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/110371-3-1-1.wav.png
# FileCount = 55: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/110389-3-0-0.wav.png
# FileCount = 56: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/110688-3-0-11.wav.png
# FileCount = 57: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/110688-3-0-17.wav.png
# FileCount = 58: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/110688-3-0-2.wav.png
# FileCount = 59: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/110688-3-0-32.wav.png
# FileCount = 60: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/110918-3-0-1.wav.png
# FileCount = 61: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/110918-3-0-26.wav.png
# FileCount = 62: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/110918-3-0-40.wav.png
# FileCount = 63: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/110918-3-0-9.wav.png
# FileCount = 64: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/112195-3-0-38.wav.png
# FileCount = 65: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/112195-3-0-48.wav.png
# FileCount = 66: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/112195-3-0-57.wav.png
# FileCount = 67: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/112195-3-0-80.wav.png
# FileCount = 68: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/113785-3-0-0.wav.png
# FileCount = 69: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/113785-3-1-0.wav.png
# FileCount = 70: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/114280-3-0-0.wav.png
# FileCount = 71: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/114280-3-0-1.wav.png
# FileCount = 72: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/114587-3-0-2.wav.png
# FileCount = 73: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/114587-3-0-4.wav.png
# FileCount = 74: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/114587-3-0-5.wav.png
# FileCount = 75: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/114587-3-0-7.wav.png
# FileCount = 76: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/115411-3-0-0.wav.png
# FileCount = 77: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/115411-3-2-0.wav.png
# FileCount = 78: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/115411-3-3-0.wav.png
# FileCount = 79: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/115535-3-0-0.wav.png
# FileCount = 80: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/115536-3-0-0.wav.png
# FileCount = 81: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/115537-3-0-0.wav.png
# FileCount = 82: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/116163-3-0-0.wav.png
# FileCount = 83: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/116163-3-1-0.wav.png
# FileCount = 84: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/116163-3-2-0.wav.png
# FileCount = 85: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/116400-3-0-2.wav.png
# FileCount = 86: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/116400-3-1-0.wav.png
# FileCount = 87: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/116400-3-1-1.wav.png
# FileCount = 88: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/116400-3-1-2.wav.png
# FileCount = 89: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/116483-3-0-1.wav.png
# FileCount = 90: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/116483-3-0-2.wav.png
# FileCount = 91: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/116483-3-1-0.wav.png
# FileCount = 92: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/116483-3-1-2.wav.png
# FileCount = 93: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/116484-3-0-12.wav.png
# FileCount = 94: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/116484-3-0-16.wav.png
# FileCount = 95: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/116484-3-0-6.wav.png
# FileCount = 96: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/116484-3-0-8.wav.png
# FileCount = 97: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/116485-3-0-4.wav.png
# FileCount = 98: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/116485-3-0-6.wav.png
# FileCount = 99: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/116485-3-2-0.wav.png
# FileCount = 100: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/116485-3-2-4.wav.png
# FileCount = 101: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/117048-3-0-17.wav.png
# FileCount = 102: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/117048-3-0-23.wav.png
# FileCount = 103: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/117048-3-0-25.wav.png
# FileCount = 104: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/117048-3-0-35.wav.png
# FileCount = 105: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/117072-3-0-11.wav.png
# FileCount = 106: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/117072-3-0-14.wav.png
# FileCount = 107: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/117072-3-0-19.wav.png
# FileCount = 108: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/117072-3-0-8.wav.png
# FileCount = 109: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/11722-3-0-0.wav.png
# FileCount = 110: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/11722-3-1-0.wav.png
# FileCount = 111: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/117271-3-0-0.wav.png
# FileCount = 112: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/117271-3-0-1.wav.png
# FileCount = 113: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/117271-3-0-2.wav.png
# FileCount = 114: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/117271-3-0-3.wav.png
# FileCount = 115: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/118072-3-0-0.wav.png
# FileCount = 116: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/118101-3-0-0.wav.png
# FileCount = 117: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/118101-3-0-3.wav.png
# FileCount = 118: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/118101-3-0-4.wav.png
# FileCount = 119: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/118101-3-0-6.wav.png
# FileCount = 120: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/118587-3-0-2.wav.png
# FileCount = 121: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/118587-3-0-21.wav.png
# FileCount = 122: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/118587-3-0-6.wav.png
# FileCount = 123: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/118961-3-0-0.wav.png
# FileCount = 124: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/118962-3-0-0.wav.png
# FileCount = 125: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/118963-3-0-0.wav.png
# FileCount = 126: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/118964-3-0-0.wav.png
# FileCount = 127: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/119420-3-0-0.wav.png
# FileCount = 128: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/119420-3-1-0.wav.png
# FileCount = 129: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/121888-3-0-0.wav.png
# FileCount = 130: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/122199-3-1-1.wav.png
# FileCount = 131: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/122199-3-1-2.wav.png
# FileCount = 132: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/122199-3-1-3.wav.png
# FileCount = 133: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/122199-3-1-6.wav.png
# FileCount = 134: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/125523-3-0-1.wav.png
# FileCount = 135: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/125523-3-0-11.wav.png
# FileCount = 136: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/125523-3-0-3.wav.png
# FileCount = 137: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/125554-3-0-0.wav.png
# FileCount = 138: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/125574-3-0-0.wav.png
# FileCount = 139: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/125791-3-0-12.wav.png
# FileCount = 140: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/125791-3-0-13.wav.png
# FileCount = 141: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/125791-3-0-15.wav.png
# FileCount = 142: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/125791-3-0-9.wav.png
# FileCount = 143: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/12647-3-0-0.wav.png
# FileCount = 144: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/12647-3-1-0.wav.png
# FileCount = 145: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/12647-3-2-0.wav.png
# FileCount = 146: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/12647-3-3-0.wav.png
# FileCount = 147: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/126521-3-0-12.wav.png
# FileCount = 148: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/126521-3-0-17.wav.png
# FileCount = 149: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/126521-3-0-18.wav.png
# FileCount = 150: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/126521-3-0-2.wav.png
# FileCount = 151: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/128030-3-0-0.wav.png
# FileCount = 152: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/128030-3-1-0.wav.png
# FileCount = 153: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/128030-3-2-0.wav.png
# FileCount = 154: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/128240-3-0-1.wav.png
# FileCount = 155: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/128240-3-0-20.wav.png
# FileCount = 156: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/128240-3-0-39.wav.png
# FileCount = 157: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/128240-3-0-42.wav.png
# FileCount = 158: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/128470-3-0-0.wav.png
# FileCount = 159: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/128470-3-0-1.wav.png
# FileCount = 160: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/128470-3-0-5.wav.png
# FileCount = 161: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/128470-3-0-8.wav.png
# FileCount = 162: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/128891-3-0-2.wav.png
# FileCount = 163: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/128891-3-0-4.wav.png
# FileCount = 164: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/128891-3-0-5.wav.png
# FileCount = 165: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/130030-3-0-0.wav.png
# FileCount = 166: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/131199-3-0-0.wav.png
# FileCount = 167: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/13577-3-0-0.wav.png
# FileCount = 168: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/13577-3-0-2.wav.png
# FileCount = 169: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/13577-3-5-0.wav.png
# FileCount = 170: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/137803-3-0-0.wav.png
# FileCount = 171: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/137803-3-0-1.wav.png
# FileCount = 172: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/137803-3-0-2.wav.png
# FileCount = 173: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/138015-3-0-1.wav.png
# FileCount = 174: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/138015-3-0-5.wav.png
# FileCount = 175: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/138015-3-0-7.wav.png
# FileCount = 176: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/139948-3-0-0.wav.png
# FileCount = 177: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/139948-3-1-0.wav.png
# FileCount = 178: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/139948-3-2-0.wav.png
# FileCount = 179: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/139948-3-4-0.wav.png
# FileCount = 180: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/142641-3-0-0.wav.png
# FileCount = 181: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/14358-3-0-26.wav.png
# FileCount = 182: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/14358-3-0-7.wav.png
# FileCount = 183: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/14358-3-0-85.wav.png
# FileCount = 184: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/14358-3-0-90.wav.png
# FileCount = 185: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/144028-3-0-0.wav.png
# FileCount = 186: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/144028-3-1-0.wav.png
# FileCount = 187: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/144028-3-1-1.wav.png
# FileCount = 188: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/14468-3-0-2.wav.png
# FileCount = 189: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/14468-3-0-3.wav.png
# FileCount = 190: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/14468-3-1-0.wav.png
# FileCount = 191: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/14468-3-5-0.wav.png
# FileCount = 192: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/144885-3-0-0.wav.png
# FileCount = 193: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/146343-3-0-0.wav.png
# FileCount = 194: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/147672-3-0-0.wav.png
# FileCount = 195: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/147672-3-1-0.wav.png
# FileCount = 196: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/147672-3-2-0.wav.png
# FileCount = 197: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/150341-3-0-0.wav.png
# FileCount = 198: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/150341-3-1-0.wav.png
# FileCount = 199: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/152588-3-0-0.wav.png
# FileCount = 200: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/152588-3-1-0.wav.png
# FileCount = 201: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/152588-3-2-0.wav.png
# FileCount = 202: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/152588-3-3-0.wav.png
# FileCount = 203: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/155294-3-0-0.wav.png
# FileCount = 204: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/155299-3-0-1.wav.png
# FileCount = 205: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/155299-3-1-0.wav.png
# FileCount = 206: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/155299-3-1-1.wav.png
# FileCount = 207: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/155299-3-1-2.wav.png
# FileCount = 208: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/155309-3-0-0.wav.png
# /usr/local/lib/python3.7/dist-packages/librosa/filters.py:239: UserWarning: Empty filters detected in mel frequency basis. Some channels will produce empty responses. Try increasing your sampling rate (and fmax) or reducing n_mels.
#   "Empty filters detected in mel frequency basis. "
# FileCount = 209: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/155310-3-0-0.wav.png
# FileCount = 210: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/155311-3-0-0.wav.png
# FileCount = 211: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/155312-3-0-0.wav.png
# FileCount = 212: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/155313-3-0-0.wav.png
# FileCount = 213: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/155314-3-0-1.wav.png
# FileCount = 214: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/155314-3-0-2.wav.png
# FileCount = 215: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/155314-3-0-5.wav.png
# FileCount = 216: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/155315-3-0-0.wav.png
# FileCount = 217: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/155317-3-0-0.wav.png
# FileCount = 218: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/155320-3-0-0.wav.png
# FileCount = 219: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/155488-3-0-6.wav.png
# FileCount = 220: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/155488-3-2-0.wav.png
# FileCount = 221: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/155488-3-3-0.wav.png
# FileCount = 222: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/155488-3-3-1.wav.png
# FileCount = 223: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/156418-3-0-0.wav.png
# FileCount = 224: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/156418-3-0-1.wav.png
# FileCount = 225: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/156418-3-1-0.wav.png
# FileCount = 226: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/156418-3-2-0.wav.png
# FileCount = 227: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/157322-3-0-3.wav.png
# FileCount = 228: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/157322-3-0-4.wav.png
# FileCount = 229: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/157322-3-0-5.wav.png
# FileCount = 230: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/157322-3-0-6.wav.png
# FileCount = 231: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/157649-3-0-0.wav.png
# FileCount = 232: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/157649-3-0-1.wav.png
# FileCount = 233: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/157649-3-1-1.wav.png
# FileCount = 234: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/157649-3-2-0.wav.png
# FileCount = 235: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/157695-3-0-19.wav.png
# FileCount = 236: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/157695-3-0-2.wav.png
# FileCount = 237: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/157695-3-0-27.wav.png
# FileCount = 238: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/157695-3-0-8.wav.png
# FileCount = 239: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/157950-3-0-0.wav.png
# FileCount = 240: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/158607-3-0-0.wav.png
# FileCount = 241: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/158607-3-1-0.wav.png
# FileCount = 242: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/158607-3-2-0.wav.png
# FileCount = 243: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/159176-3-0-0.wav.png
# FileCount = 244: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/159726-3-0-0.wav.png
# FileCount = 245: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/159726-3-1-0.wav.png
# FileCount = 246: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/160092-3-0-0.wav.png
# FileCount = 247: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/160093-3-0-0.wav.png
# FileCount = 248: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/160094-3-0-0.wav.png
# FileCount = 249: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/160366-3-0-13.wav.png
# FileCount = 250: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/160366-3-0-4.wav.png
# FileCount = 251: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/160366-3-0-7.wav.png
# FileCount = 252: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/160366-3-0-8.wav.png
# FileCount = 253: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/160575-3-0-0.wav.png
# FileCount = 254: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/160575-3-1-0.wav.png
# FileCount = 255: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/160575-3-4-0.wav.png
# FileCount = 256: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/160575-3-7-0.wav.png
# FileCount = 257: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/161922-3-1-4.wav.png
# FileCount = 258: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/161922-3-1-5.wav.png
# FileCount = 259: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/161922-3-1-6.wav.png
# FileCount = 260: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/161922-3-2-0.wav.png
# FileCount = 261: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/161923-3-0-0.wav.png
# FileCount = 262: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/161923-3-0-12.wav.png
# FileCount = 263: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/161923-3-0-19.wav.png
# FileCount = 264: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/161923-3-0-5.wav.png
# FileCount = 265: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/162148-3-0-0.wav.png
# FileCount = 266: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/163459-3-0-0.wav.png
# FileCount = 267: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/164311-3-0-0.wav.png
# FileCount = 268: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/164311-3-1-0.wav.png
# FileCount = 269: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/164312-3-0-0.wav.png
# FileCount = 270: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/164312-3-1-0.wav.png
# FileCount = 271: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/164312-3-3-0.wav.png
# FileCount = 272: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/164312-3-4-0.wav.png
# FileCount = 273: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/165567-3-0-0.wav.png
# FileCount = 274: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/165567-3-2-0.wav.png
# FileCount = 275: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/165567-3-3-0.wav.png
# FileCount = 276: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/165567-3-4-0.wav.png
# FileCount = 277: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/166268-3-0-0.wav.png
# FileCount = 278: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/166268-3-1-0.wav.png
# FileCount = 279: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/166268-3-2-0.wav.png
# FileCount = 280: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/166421-3-0-29.wav.png
# FileCount = 281: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/166421-3-0-31.wav.png
# FileCount = 282: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/166421-3-0-5.wav.png
# FileCount = 283: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/166489-3-0-1.wav.png
# FileCount = 284: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/166489-3-0-2.wav.png
# FileCount = 285: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/166489-3-0-4.wav.png
# FileCount = 286: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/170015-3-0-0.wav.png
# FileCount = 287: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/171464-3-0-0.wav.png
# FileCount = 288: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/171464-3-1-0.wav.png
# FileCount = 289: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/171464-3-2-0.wav.png
# FileCount = 290: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/173993-3-0-25.wav.png
# FileCount = 291: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/173993-3-0-39.wav.png
# FileCount = 292: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/173993-3-0-51.wav.png
# FileCount = 293: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/173993-3-0-52.wav.png
# FileCount = 294: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/173994-3-0-14.wav.png
# FileCount = 295: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/173994-3-0-3.wav.png
# FileCount = 296: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/173994-3-0-44.wav.png
# FileCount = 297: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/173994-3-0-45.wav.png
# FileCount = 298: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/173995-3-0-0.wav.png
# FileCount = 299: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/173995-3-0-11.wav.png
# FileCount = 300: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/173995-3-0-27.wav.png
# FileCount = 301: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/173995-3-0-3.wav.png
# FileCount = 302: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/174026-3-1-0.wav.png
# FileCount = 303: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/174026-3-1-1.wav.png
# FileCount = 304: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/174026-3-1-5.wav.png
# FileCount = 305: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/174026-3-2-2.wav.png
# FileCount = 306: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/17486-3-0-0.wav.png
# FileCount = 307: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/17486-3-1-0.wav.png
# FileCount = 308: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/17486-3-2-0.wav.png
# FileCount = 309: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/174873-3-5-1.wav.png
# FileCount = 310: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/174873-3-5-10.wav.png
# FileCount = 311: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/174873-3-5-12.wav.png
# FileCount = 312: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/174873-3-5-13.wav.png
# FileCount = 313: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/174994-3-0-0.wav.png
# FileCount = 314: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/174994-3-0-1.wav.png
# FileCount = 315: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/174994-3-0-2.wav.png
# FileCount = 316: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/174994-3-0-4.wav.png
# FileCount = 317: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/175915-3-0-0.wav.png
# FileCount = 318: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/175915-3-0-1.wav.png
# FileCount = 319: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/175915-3-0-3.wav.png
# FileCount = 320: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/175915-3-1-8.wav.png
# FileCount = 321: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/175917-3-0-3.wav.png
# FileCount = 322: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/175917-3-1-1.wav.png
# FileCount = 323: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/175917-3-2-2.wav.png
# FileCount = 324: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/175917-3-4-1.wav.png
# FileCount = 325: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/17615-3-0-0.wav.png
# FileCount = 326: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/17615-3-0-3.wav.png
# FileCount = 327: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/17615-3-0-4.wav.png
# FileCount = 328: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/17615-3-0-6.wav.png
# FileCount = 329: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/176257-3-0-0.wav.png
# FileCount = 330: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/176258-3-1-12.wav.png
# FileCount = 331: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/176258-3-1-13.wav.png
# FileCount = 332: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/176258-3-1-18.wav.png
# FileCount = 333: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/176258-3-1-2.wav.png
# FileCount = 334: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/176783-3-0-11.wav.png
# FileCount = 335: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/176783-3-0-3.wav.png
# FileCount = 336: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/176783-3-0-5.wav.png
# FileCount = 337: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/176783-3-1-0.wav.png
# FileCount = 338: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/177620-3-0-20.wav.png
# FileCount = 339: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/177620-3-0-21.wav.png
# FileCount = 340: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/177620-3-0-25.wav.png
# FileCount = 341: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/177620-3-0-8.wav.png
# FileCount = 342: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/17810-3-0-0.wav.png
# FileCount = 343: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/17810-3-1-0.wav.png
# FileCount = 344: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/178118-3-0-0.wav.png
# FileCount = 345: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/178118-3-1-0.wav.png
# FileCount = 346: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/178118-3-2-0.wav.png
# FileCount = 347: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/178497-3-0-1.wav.png
# FileCount = 348: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/178497-3-0-3.wav.png
# FileCount = 349: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/178497-3-0-4.wav.png
# FileCount = 350: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/178497-3-0-6.wav.png
# FileCount = 351: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/179096-3-0-1.wav.png
# FileCount = 352: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/179096-3-0-10.wav.png
# FileCount = 353: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/179096-3-0-5.wav.png
# FileCount = 354: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/179096-3-0-9.wav.png
# FileCount = 355: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/179386-3-0-0.wav.png
# FileCount = 356: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/179386-3-0-1.wav.png
# FileCount = 357: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/179386-3-0-2.wav.png
# FileCount = 358: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/179386-3-0-3.wav.png
# FileCount = 359: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/180052-3-0-0.wav.png
# FileCount = 360: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/180052-3-0-1.wav.png
# FileCount = 361: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/180052-3-0-3.wav.png
# FileCount = 362: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/180052-3-0-4.wav.png
# FileCount = 363: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/180256-3-0-0.wav.png
# FileCount = 364: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/180256-3-0-1.wav.png
# FileCount = 365: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/180256-3-0-2.wav.png
# FileCount = 366: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/180256-3-0-3.wav.png
# FileCount = 367: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/180257-3-0-1.wav.png
# FileCount = 368: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/180257-3-0-3.wav.png
# FileCount = 369: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/180257-3-0-4.wav.png
# FileCount = 370: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/180257-3-0-5.wav.png
# FileCount = 371: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/180977-3-1-0.wav.png
# FileCount = 372: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/180977-3-1-1.wav.png
# FileCount = 373: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/180977-3-1-5.wav.png
# FileCount = 374: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/181725-3-0-16.wav.png
# FileCount = 375: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/181725-3-0-22.wav.png
# FileCount = 376: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/181725-3-0-37.wav.png
# FileCount = 377: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/183989-3-1-18.wav.png
# FileCount = 378: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/183989-3-1-21.wav.png
# FileCount = 379: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/183989-3-1-23.wav.png
# FileCount = 380: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/183989-3-1-25.wav.png
# FileCount = 381: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/183992-3-0-10.wav.png
# FileCount = 382: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/183992-3-0-3.wav.png
# FileCount = 383: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/183992-3-0-6.wav.png
# FileCount = 384: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/183992-3-0-9.wav.png
# FileCount = 385: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/18453-3-0-0.wav.png
# FileCount = 386: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/184575-3-0-0.wav.png
# FileCount = 387: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/184575-3-0-1.wav.png
# FileCount = 388: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/184575-3-0-2.wav.png
# FileCount = 389: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/184575-3-0-3.wav.png
# FileCount = 390: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/184725-3-0-1.wav.png
# FileCount = 391: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/184725-3-0-2.wav.png
# FileCount = 392: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/184725-3-0-4.wav.png
# FileCount = 393: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/184725-3-0-5.wav.png
# FileCount = 394: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/18581-3-0-0.wav.png
# FileCount = 395: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/18581-3-0-5.wav.png
# FileCount = 396: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/18581-3-1-1.wav.png
# FileCount = 397: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/18581-3-1-3.wav.png
# FileCount = 398: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/187378-3-0-12.wav.png
# FileCount = 399: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/187378-3-0-19.wav.png
# FileCount = 400: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/187378-3-0-30.wav.png
# FileCount = 401: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/187378-3-0-7.wav.png
# FileCount = 402: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/189846-3-0-0.wav.png
# FileCount = 403: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/189846-3-1-0.wav.png
# FileCount = 404: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/189846-3-3-0.wav.png
# FileCount = 405: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/189846-3-4-0.wav.png
# FileCount = 406: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/189895-3-0-0.wav.png
# FileCount = 407: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/190680-3-1-0.wav.png
# FileCount = 408: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/190680-3-4-0.wav.png
# FileCount = 409: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/190680-3-6-0.wav.png
# FileCount = 410: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/190996-3-0-0.wav.png
# FileCount = 411: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/190996-3-0-1.wav.png
# FileCount = 412: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/190996-3-0-8.wav.png
# FileCount = 413: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/191382-3-0-0.wav.png
# FileCount = 414: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/191382-3-0-5.wav.png
# FileCount = 415: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/191382-3-1-0.wav.png
# FileCount = 416: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/191382-3-1-1.wav.png
# FileCount = 417: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/191687-3-0-0.wav.png
# FileCount = 418: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/191687-3-0-11.wav.png
# FileCount = 419: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/191687-3-0-15.wav.png
# FileCount = 420: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/191687-3-0-5.wav.png
# FileCount = 421: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/19218-3-0-0.wav.png
# FileCount = 422: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/192236-3-0-2.wav.png
# FileCount = 423: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/192236-3-0-4.wav.png
# FileCount = 424: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/192236-3-0-6.wav.png
# FileCount = 425: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/192236-3-0-8.wav.png
# FileCount = 426: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/193394-3-0-10.wav.png
# FileCount = 427: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/193394-3-0-11.wav.png
# FileCount = 428: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/193394-3-0-4.wav.png
# FileCount = 429: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/193394-3-0-7.wav.png
# FileCount = 430: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/194753-3-0-0.wav.png
# FileCount = 431: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/194753-3-1-0.wav.png
# FileCount = 432: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/194753-3-2-0.wav.png
# FileCount = 433: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/194753-3-3-0.wav.png
# FileCount = 434: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/194754-3-0-0.wav.png
# FileCount = 435: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/194754-3-0-1.wav.png
# FileCount = 436: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/194754-3-0-2.wav.png
# FileCount = 437: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/19496-3-0-0.wav.png
# FileCount = 438: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/19496-3-1-0.wav.png
# ...
# FileCount = 695: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/49808-3-0-6.wav.png
# FileCount = 696: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/49808-3-1-22.wav.png
# FileCount = 697: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/49808-3-1-8.wav.png
# FileCount = 698: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/49809-3-0-0.wav.png
# FileCount = 699: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/49809-3-3-0.wav.png
# FileCount = 700: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/49809-3-4-0.wav.png
# FileCount = 701: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/50223-3-0-1.wav.png
# FileCount = 702: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/50223-3-0-10.wav.png
# FileCount = 703: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/50223-3-0-3.wav.png
# FileCount = 704: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/50223-3-0-6.wav.png
# FileCount = 705: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/50612-3-0-0.wav.png
# FileCount = 706: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/50613-3-0-0.wav.png
# FileCount = 707: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/50614-3-0-0.wav.png
# FileCount = 708: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/50885-3-0-2.wav.png
# FileCount = 709: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/50885-3-0-3.wav.png
# FileCount = 710: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/50885-3-0-4.wav.png
# FileCount = 711: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/50885-3-0-5.wav.png
# FileCount = 712: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/51022-3-13-0.wav.png
# FileCount = 713: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/51022-3-29-0.wav.png
# FileCount = 714: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/51022-3-30-4.wav.png
# FileCount = 715: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/51022-3-7-0.wav.png
# FileCount = 716: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/51024-3-0-16.wav.png
# FileCount = 717: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/51024-3-0-2.wav.png
# FileCount = 718: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/51024-3-0-23.wav.png
# FileCount = 719: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/51024-3-0-3.wav.png
# FileCount = 720: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/51027-3-0-7.wav.png
# FileCount = 721: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/51027-3-0-9.wav.png
# FileCount = 722: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/51027-3-1-1.wav.png
# FileCount = 723: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/51027-3-1-4.wav.png
# FileCount = 724: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/52077-3-0-13.wav.png
# FileCount = 725: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/52077-3-0-17.wav.png
# FileCount = 726: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/52077-3-0-3.wav.png
# FileCount = 727: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/52077-3-0-8.wav.png
# FileCount = 728: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/52171-3-2-0.wav.png
# FileCount = 729: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/52171-3-3-0.wav.png
# FileCount = 730: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/52171-3-6-0.wav.png
# FileCount = 731: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/52171-3-6-1.wav.png
# FileCount = 732: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/52441-3-0-0.wav.png
# FileCount = 733: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/52441-3-0-13.wav.png
# FileCount = 734: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/52441-3-0-8.wav.png
# FileCount = 735: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/52441-3-1-2.wav.png
# FileCount = 736: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/52633-3-0-1.wav.png
# FileCount = 737: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/52633-3-0-2.wav.png
# FileCount = 738: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/52633-3-0-8.wav.png
# FileCount = 739: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/52633-3-0-9.wav.png
# FileCount = 740: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/52740-3-0-0.wav.png
# FileCount = 741: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/52740-3-0-1.wav.png
# FileCount = 742: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/52740-3-0-2.wav.png
# FileCount = 743: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/52740-3-0-3.wav.png
# FileCount = 744: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/54545-3-0-0.wav.png
# FileCount = 745: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/54545-3-0-1.wav.png
# FileCount = 746: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/54545-3-0-2.wav.png
# FileCount = 747: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/54823-3-0-0.wav.png
# FileCount = 748: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/54823-3-1-0.wav.png
# FileCount = 749: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/54823-3-2-1.wav.png
# FileCount = 750: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/54858-3-0-0.wav.png
# FileCount = 751: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/54858-3-1-2.wav.png
# FileCount = 752: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/54858-3-2-0.wav.png
# FileCount = 753: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/55013-3-0-1.wav.png
# FileCount = 754: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/55013-3-0-3.wav.png
# FileCount = 755: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/55013-3-0-4.wav.png
# FileCount = 756: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/55013-3-0-7.wav.png
# FileCount = 757: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/57105-3-0-1.wav.png
# FileCount = 758: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/57105-3-1-0.wav.png
# FileCount = 759: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/57105-3-4-2.wav.png
# FileCount = 760: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/57105-3-4-4.wav.png
# FileCount = 761: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/57553-3-0-0.wav.png
# FileCount = 762: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/57553-3-1-0.wav.png
# FileCount = 763: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/57553-3-2-0.wav.png
# FileCount = 764: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/57596-3-0-0.wav.png
# FileCount = 765: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/57596-3-1-0.wav.png
# FileCount = 766: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/58382-3-0-0.wav.png
# FileCount = 767: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/59513-3-0-0.wav.png
# FileCount = 768: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/59513-3-0-1.wav.png
# FileCount = 769: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/59513-3-0-3.wav.png
# FileCount = 770: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/59513-3-0-4.wav.png
# FileCount = 771: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/59800-3-0-0.wav.png
# FileCount = 772: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/59800-3-1-0.wav.png
# FileCount = 773: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/59800-3-2-0.wav.png
# FileCount = 774: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/59800-3-3-1.wav.png
# FileCount = 775: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/61077-3-0-0.wav.png
# FileCount = 776: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/61077-3-1-0.wav.png
# FileCount = 777: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/61077-3-2-0.wav.png
# FileCount = 778: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/61077-3-3-0.wav.png
# FileCount = 779: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/61250-3-0-31.wav.png
# FileCount = 780: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/61250-3-0-36.wav.png
# FileCount = 781: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/61250-3-0-47.wav.png
# FileCount = 782: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/61250-3-0-62.wav.png
# FileCount = 783: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/62048-3-0-2.wav.png
# FileCount = 784: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/62048-3-0-3.wav.png
# FileCount = 785: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/62048-3-0-4.wav.png
# FileCount = 786: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/62048-3-0-5.wav.png
# FileCount = 787: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/63261-3-0-0.wav.png
# FileCount = 788: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/63261-3-0-1.wav.png
# FileCount = 789: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/63292-3-0-0.wav.png
# FileCount = 790: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/63292-3-0-1.wav.png
# FileCount = 791: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/63932-3-0-1.wav.png
# FileCount = 792: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/63932-3-0-2.wav.png
# FileCount = 793: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/63932-3-1-0.wav.png
# FileCount = 794: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/63932-3-1-1.wav.png
# FileCount = 795: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/65381-3-0-3.wav.png
# FileCount = 796: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/65381-3-0-6.wav.png
# FileCount = 797: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/65381-3-0-7.wav.png
# FileCount = 798: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/65745-3-0-21.wav.png
# FileCount = 799: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/65745-3-0-49.wav.png
# FileCount = 800: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/train/65745-3-0-61.wav.png
# FileCount = 801: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/test/65745-3-0-88.wav.png
# FileCount = 802: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/test/65749-3-1-12.wav.png
# FileCount = 803: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/test/65749-3-1-14.wav.png
# FileCount = 804: Working on spectogram /content/gdrive/MyDrive/urbansound/dataset/test/65749-3-1-24.wav.png
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-c45a591132fd> in <module>()
#      41     fig2.set_size_inches(2.9, 2.98)
#      42     #plt.imshow(cmap='gray_r')
# ---> 43     plt.savefig(pngfile, dpi=100, bbox_inches='tight', pad_inches=0, format='png')
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/pyplot.py in savefig(*args, **kwargs)
#     722     fig = gcf()
#     723     res = fig.savefig(*args, **kwargs)
# --> 724     fig.canvas.draw_idle()   # need this if 'transparent=True' to reset colors
#     725     return res
#     726
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/backend_bases.py in draw_idle(self, *args, **kwargs)
#    1945         if not self._is_idle_drawing:
#    1946             with self._idle_draw_cntx():
# -> 1947                 self.draw(*args, **kwargs)
#    1948
#    1949     @cbook.deprecated("3.2")
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py in draw(self)
#     391              (self.toolbar._wait_cursor_for_draw_cm() if self.toolbar
#     392               else nullcontext()):
# --> 393             self.figure.draw(self.renderer)
#     394             # A GUI class may be need to update a window using this draw, so
#     395             # don't forget to call the superclass.
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      36                 renderer.start_filter()
#      37
# ---> 38             return draw(artist, renderer, *args, **kwargs)
#      39         finally:
#      40             if artist.get_agg_filter() is not None:
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/figure.py in draw(self, renderer)
#    1734             self.patch.draw(renderer)
#    1735             mimage._draw_list_compositing_images(
# -> 1736                 renderer, self, artists, self.suppressComposite)
#    1737
#    1738             renderer.close_group('figure')
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     135     if not_composite or not has_images:
#     136         for a in artists:
# --> 137             a.draw(renderer)
#     138     else:
#     139         # Composite any adjacent images together
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      36                 renderer.start_filter()
#      37
# ---> 38             return draw(artist, renderer, *args, **kwargs)
#      39         finally:
#      40             if artist.get_agg_filter() is not None:
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/axes/_base.py in draw(self, renderer, inframe)
#    2628             renderer.stop_rasterizing()
#    2629
# -> 2630         mimage._draw_list_compositing_images(renderer, self, artists)
#    2631
#    2632         renderer.close_group('axes')
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     135     if not_composite or not has_images:
#     136         for a in artists:
# --> 137             a.draw(renderer)
#     138     else:
#     139         # Composite any adjacent images together
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      36                 renderer.start_filter()
#      37
# ---> 38             return draw(artist, renderer, *args, **kwargs)
#      39         finally:
#      40             if artist.get_agg_filter() is not None:
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/collections.py in draw(self, renderer)
#    2071                 gc, transform.frozen(), self._meshWidth, self._meshHeight,
#    2072                 coordinates, offsets, transOffset, self.get_facecolor(),
# -> 2073                 self._antialiased, self.get_edgecolors())
#    2074         gc.restore()
#    2075         renderer.close_group(self.__class__.__name__)
#
# KeyboardInterrupt:
