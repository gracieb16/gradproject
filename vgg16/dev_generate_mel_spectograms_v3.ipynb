# %%
from google.colab import drive #Only if you are using Google Drive
drive.mount('/content/gdrive')
drive.mount("/content/gdrive", force_remount=True)
# %cd /content/gdrive/My\ Drive/
# Out:
# Mounted at /content/gdrive
# Mounted at /content/gdrive
# /content/gdrive/My Drive

# %%
! ls -al /content/gdrive/MyDrive/devwav | wc
# Out:
# ls: cannot open directory '/content/gdrive/MyDrive/devwav': Input/output error
#       0       0       0

# %%
import numpy as np
import librosa, librosa.display
import matplotlib.pyplot as plt
import pandas as pd
import time
devf = '/content/gdrive/My Drive/dev.csv'
devcsv = pd.read_csv(devf)
dfdev = pd.DataFrame(devcsv)
dftrain = dfdev[dfdev['split'] == 'train'].copy()
print(dftrain.info())
print(dftrain.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 36796 entries, 0 to 40965
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   fname   36796 non-null  int64
#  1   labels  36796 non-null  object
#  2   mids    36796 non-null  object
#  3   split   36796 non-null  object
# dtypes: int64(1), object(3)
# memory usage: 1.4+ MB
# None
#    fname                                             labels  \
# 0  64760  Electric_guitar,Guitar,Plucked_string_instrume...
# 1  16399  Electric_guitar,Guitar,Plucked_string_instrume...
# 2  16401  Electric_guitar,Guitar,Plucked_string_instrume...
# 3  16402  Electric_guitar,Guitar,Plucked_string_instrume...
# 4  16404  Electric_guitar,Guitar,Plucked_string_instrume...
#
#                                             mids  split
# 0  /m/02sgy,/m/0342h,/m/0fx80y,/m/04szw,/m/04rlf  train
# 1  /m/02sgy,/m/0342h,/m/0fx80y,/m/04szw,/m/04rlf  train
# 2  /m/02sgy,/m/0342h,/m/0fx80y,/m/04szw,/m/04rlf  train
# 3  /m/02sgy,/m/0342h,/m/0fx80y,/m/04szw,/m/04rlf  train
# 4  /m/02sgy,/m/0342h,/m/0fx80y,/m/04szw,/m/04rlf  train

# %%
dev_audio_dir = '/content/gdrive/MyDrive/devwav/'
dev_png_dir = '/content/gdrive/MyDrive/trainpng2/'
dftrain["wavfiles"] = dftrain.apply(lambda row: dev_audio_dir+str(row.fname)+'.wav', axis=1)
dftrain["figfiles"] = dftrain.apply(lambda row: dev_png_dir+str(row.fname)+'.png', axis=1)

dftrain.info()
dftrain.head()
startime = time.ctime()
print(time.ctime())
srhz=44100
frame_size = int(srhz/1000*960)
frame_shift = int(srhz/1000*25)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 36796 entries, 0 to 40965
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   fname     36796 non-null  int64
#  1   labels    36796 non-null  object
#  2   mids      36796 non-null  object
#  3   split     36796 non-null  object
#  4   wavfiles  36796 non-null  object
#  5   figfiles  36796 non-null  object
# dtypes: int64(1), object(5)
# memory usage: 2.0+ MB
# Wed Apr 27 09:14:44 2022

# %%
rowcount=dftrain.shape[0]
print(rowcount)
df_1 = dftrain.iloc[:4000,:]
df_2 = dftrain.iloc[4001:8000,:]
df_3 = dftrain.iloc[8001:12000,:]
df_4 = dftrain.iloc[12001:16000,:]
df_5 = dftrain.iloc[16001:20000,:]
df_6 = dftrain.iloc[20001:24000,:]
df_7 = dftrain.iloc[24001:28000,:]
df_8 = dftrain.iloc[28001:32000,:]
df_9 = dftrain.iloc[32001:36000,:]
df_10 = dftrain.iloc[36001:,:]
# Out:
# 36796

# %%
filect = 0 
print('Working on subset from df_1 = dftrain.iloc[:4000,:]')
for i in df_1.itertuples():
    filect = filect+1
    file = i[5]
    pngfile = i[6]
    print('FileCount = '+str(filect)+': Working on spectogram '+pngfile)
    signal, sr = librosa.load(file, sr=None)
    # my parameters
    hop_length = 11025 # in num. of samples
    n_fft = 42336 # window in num. of samples
    hop_length_duration = float(hop_length)/sr
    n_fft_duration = float(n_fft)/sr
    # Mel filter banks
    filter_banks = librosa.filters.mel(n_fft=n_fft, sr=sr, n_mels=64)
    stft = librosa.stft(signal, n_fft=n_fft, hop_length=hop_length)
    # This will yield 96-length spectrograms
    spectrogram = np.abs(stft)
    # converted to 64 bin log-scaled Mel spectrogram,
    melspec = librosa.feature.melspectrogram(y=signal, sr=sr, S=spectrogram, n_fft=n_fft, hop_length=hop_length, win_length=None, window='hann', center=True, pad_mode='reflect', n_mels=64)
    log_mel_spectrogram = librosa.power_to_db(melspec, ref=np.max)
    #plt.figure(figsize=(2.24, 2.24))
    fig = librosa.display.specshow(log_mel_spectrogram, hop_length=hop_length)
    fig2 = plt.gcf()
    plt.axis('off')
    fig2.set_size_inches(2.9, 2.98)
    plt.savefig(pngfile, dpi=100, bbox_inches='tight', pad_inches=0, format='png')

print('start time: ')
print(startime)
print(time.ctime())
# Out:
# Working on subset from df_1 = dftrain.iloc[:4000,:]
# FileCount = 1: Working on spectogram /content/gdrive/MyDrive/trainpng2/64760.png
# FileCount = 2: Working on spectogram /content/gdrive/MyDrive/trainpng2/16399.png
# FileCount = 3: Working on spectogram /content/gdrive/MyDrive/trainpng2/16401.png
# FileCount = 4: Working on spectogram /content/gdrive/MyDrive/trainpng2/16402.png
# FileCount = 5: Working on spectogram /content/gdrive/MyDrive/trainpng2/16404.png
# FileCount = 6: Working on spectogram /content/gdrive/MyDrive/trainpng2/64761.png
# FileCount = 7: Working on spectogram /content/gdrive/MyDrive/trainpng2/268259.png
# FileCount = 8: Working on spectogram /content/gdrive/MyDrive/trainpng2/64762.png
# FileCount = 9: Working on spectogram /content/gdrive/MyDrive/trainpng2/40515.png
# FileCount = 10: Working on spectogram /content/gdrive/MyDrive/trainpng2/40516.png
# FileCount = 11: Working on spectogram /content/gdrive/MyDrive/trainpng2/40517.png
# FileCount = 12: Working on spectogram /content/gdrive/MyDrive/trainpng2/64741.png
# FileCount = 13: Working on spectogram /content/gdrive/MyDrive/trainpng2/40523.png
# FileCount = 14: Working on spectogram /content/gdrive/MyDrive/trainpng2/64743.png
# FileCount = 15: Working on spectogram /content/gdrive/MyDrive/trainpng2/64744.png
# /usr/local/lib/python3.7/dist-packages/librosa/core/spectrum.py:224: UserWarning: n_fft=42336 is too small for input signal of length=37801
#   n_fft, y.shape[-1]
# FileCount = 16: Working on spectogram /content/gdrive/MyDrive/trainpng2/40525.png
# FileCount = 17: Working on spectogram /content/gdrive/MyDrive/trainpng2/64746.png
# FileCount = 18: Working on spectogram /content/gdrive/MyDrive/trainpng2/5318.png
# FileCount = 19: Working on spectogram /content/gdrive/MyDrive/trainpng2/4258.png
# FileCount = 20: Working on spectogram /content/gdrive/MyDrive/trainpng2/4259.png
# FileCount = 21: Working on spectogram /content/gdrive/MyDrive/trainpng2/4260.png
# FileCount = 22: Working on spectogram /content/gdrive/MyDrive/trainpng2/4261.png
# FileCount = 23: Working on spectogram /content/gdrive/MyDrive/trainpng2/4262.png
# FileCount = 24: Working on spectogram /content/gdrive/MyDrive/trainpng2/4263.png
# FileCount = 25: Working on spectogram /content/gdrive/MyDrive/trainpng2/4264.png
# /usr/local/lib/python3.7/dist-packages/librosa/core/spectrum.py:224: UserWarning: n_fft=42336 is too small for input signal of length=42104
#   n_fft, y.shape[-1]
# FileCount = 26: Working on spectogram /content/gdrive/MyDrive/trainpng2/4265.png
# FileCount = 27: Working on spectogram /content/gdrive/MyDrive/trainpng2/4266.png
# FileCount = 28: Working on spectogram /content/gdrive/MyDrive/trainpng2/4267.png
# /usr/local/lib/python3.7/dist-packages/librosa/core/spectrum.py:224: UserWarning: n_fft=42336 is too small for input signal of length=41687
#   n_fft, y.shape[-1]
# FileCount = 29: Working on spectogram /content/gdrive/MyDrive/trainpng2/4268.png
# FileCount = 30: Working on spectogram /content/gdrive/MyDrive/trainpng2/4269.png
# FileCount = 31: Working on spectogram /content/gdrive/MyDrive/trainpng2/4270.png
# /usr/local/lib/python3.7/dist-packages/librosa/core/spectrum.py:224: UserWarning: n_fft=42336 is too small for input signal of length=26139
#   n_fft, y.shape[-1]
# FileCount = 32: Working on spectogram /content/gdrive/MyDrive/trainpng2/4272.png
# /usr/local/lib/python3.7/dist-packages/librosa/core/spectrum.py:224: UserWarning: n_fft=42336 is too small for input signal of length=35108
#   n_fft, y.shape[-1]
# FileCount = 33: Working on spectogram /content/gdrive/MyDrive/trainpng2/64757.png
# FileCount = 34: Working on spectogram /content/gdrive/MyDrive/trainpng2/4276.png
# /usr/local/lib/python3.7/dist-packages/librosa/core/spectrum.py:224: UserWarning: n_fft=42336 is too small for input signal of length=33727
#   n_fft, y.shape[-1]
# FileCount = 35: Working on spectogram /content/gdrive/MyDrive/trainpng2/4277.png
# FileCount = 36: Working on spectogram /content/gdrive/MyDrive/trainpng2/4278.png
# FileCount = 37: Working on spectogram /content/gdrive/MyDrive/trainpng2/4279.png
# FileCount = 38: Working on spectogram /content/gdrive/MyDrive/trainpng2/4280.png
# FileCount = 39: Working on spectogram /content/gdrive/MyDrive/trainpng2/4281.png
# FileCount = 40: Working on spectogram /content/gdrive/MyDrive/trainpng2/4283.png
# FileCount = 41: Working on spectogram /content/gdrive/MyDrive/trainpng2/4284.png
# FileCount = 42: Working on spectogram /content/gdrive/MyDrive/trainpng2/4285.png
# FileCount = 43: Working on spectogram /content/gdrive/MyDrive/trainpng2/4286.png
# FileCount = 44: Working on spectogram /content/gdrive/MyDrive/trainpng2/4287.png
# FileCount = 45: Working on spectogram /content/gdrive/MyDrive/trainpng2/4288.png
# FileCount = 46: Working on spectogram /content/gdrive/MyDrive/trainpng2/4289.png
# FileCount = 47: Working on spectogram /content/gdrive/MyDrive/trainpng2/5314.png
# FileCount = 48: Working on spectogram /content/gdrive/MyDrive/trainpng2/4290.png
# FileCount = 49: Working on spectogram /content/gdrive/MyDrive/trainpng2/4291.png
# FileCount = 50: Working on spectogram /content/gdrive/MyDrive/trainpng2/5310.png
# FileCount = 51: Working on spectogram /content/gdrive/MyDrive/trainpng2/64703.png
# FileCount = 52: Working on spectogram /content/gdrive/MyDrive/trainpng2/5312.png
# FileCount = 53: Working on spectogram /content/gdrive/MyDrive/trainpng2/64704.png
# FileCount = 54: Working on spectogram /content/gdrive/MyDrive/trainpng2/64706.png
# FileCount = 55: Working on spectogram /content/gdrive/MyDrive/trainpng2/64707.png
# FileCount = 56: Working on spectogram /content/gdrive/MyDrive/trainpng2/64708.png
# FileCount = 57: Working on spectogram /content/gdrive/MyDrive/trainpng2/5315.png
# FileCount = 58: Working on spectogram /content/gdrive/MyDrive/trainpng2/5317.png
# FileCount = 59: Working on spectogram /content/gdrive/MyDrive/trainpng2/64711.png
# FileCount = 60: Working on spectogram /content/gdrive/MyDrive/trainpng2/64712.png
# FileCount = 61: Working on spectogram /content/gdrive/MyDrive/trainpng2/64714.png
# FileCount = 62: Working on spectogram /content/gdrive/MyDrive/trainpng2/64715.png
# FileCount = 63: Working on spectogram /content/gdrive/MyDrive/trainpng2/64717.png
# FileCount = 64: Working on spectogram /content/gdrive/MyDrive/trainpng2/64718.png
# FileCount = 65: Working on spectogram /content/gdrive/MyDrive/trainpng2/64720.png
# FileCount = 66: Working on spectogram /content/gdrive/MyDrive/trainpng2/64721.png
# FileCount = 67: Working on spectogram /content/gdrive/MyDrive/trainpng2/64722.png
# FileCount = 68: Working on spectogram /content/gdrive/MyDrive/trainpng2/64723.png
# FileCount = 69: Working on spectogram /content/gdrive/MyDrive/trainpng2/64724.png
# FileCount = 70: Working on spectogram /content/gdrive/MyDrive/trainpng2/64725.png
# FileCount = 71: Working on spectogram /content/gdrive/MyDrive/trainpng2/64726.png
# FileCount = 72: Working on spectogram /content/gdrive/MyDrive/trainpng2/64727.png
# FileCount = 73: Working on spectogram /content/gdrive/MyDrive/trainpng2/64728.png
# FileCount = 74: Working on spectogram /content/gdrive/MyDrive/trainpng2/64729.png
# FileCount = 75: Working on spectogram /content/gdrive/MyDrive/trainpng2/64730.png
# FileCount = 76: Working on spectogram /content/gdrive/MyDrive/trainpng2/64731.png
# FileCount = 77: Working on spectogram /content/gdrive/MyDrive/trainpng2/64732.png
# FileCount = 78: Working on spectogram /content/gdrive/MyDrive/trainpng2/64733.png
# FileCount = 79: Working on spectogram /content/gdrive/MyDrive/trainpng2/64734.png
# FileCount = 80: Working on spectogram /content/gdrive/MyDrive/trainpng2/64736.png
# FileCount = 81: Working on spectogram /content/gdrive/MyDrive/trainpng2/64737.png
# FileCount = 82: Working on spectogram /content/gdrive/MyDrive/trainpng2/64738.png
# FileCount = 83: Working on spectogram /content/gdrive/MyDrive/trainpng2/5350.png
# FileCount = 84: Working on spectogram /content/gdrive/MyDrive/trainpng2/5351.png
# FileCount = 85: Working on spectogram /content/gdrive/MyDrive/trainpng2/64739.png
# FileCount = 86: Working on spectogram /content/gdrive/MyDrive/trainpng2/64740.png
# FileCount = 87: Working on spectogram /content/gdrive/MyDrive/trainpng2/64747.png
# FileCount = 88: Working on spectogram /content/gdrive/MyDrive/trainpng2/266476.png
# FileCount = 89: Working on spectogram /content/gdrive/MyDrive/trainpng2/5357.png
# FileCount = 90: Working on spectogram /content/gdrive/MyDrive/trainpng2/64750.png
# FileCount = 91: Working on spectogram /content/gdrive/MyDrive/trainpng2/64742.png
# FileCount = 92: Working on spectogram /content/gdrive/MyDrive/trainpng2/5360.png
# FileCount = 93: Working on spectogram /content/gdrive/MyDrive/trainpng2/64753.png
# FileCount = 94: Working on spectogram /content/gdrive/MyDrive/trainpng2/64745.png
# FileCount = 95: Working on spectogram /content/gdrive/MyDrive/trainpng2/64755.png
# FileCount = 96: Working on spectogram /content/gdrive/MyDrive/trainpng2/5355.png
# FileCount = 97: Working on spectogram /content/gdrive/MyDrive/trainpng2/64748.png
# FileCount = 98: Working on spectogram /content/gdrive/MyDrive/trainpng2/64749.png
# FileCount = 99: Working on spectogram /content/gdrive/MyDrive/trainpng2/64751.png
# FileCount = 100: Working on spectogram /content/gdrive/MyDrive/trainpng2/64752.png
# FileCount = 101: Working on spectogram /content/gdrive/MyDrive/trainpng2/64754.png
# FileCount = 102: Working on spectogram /content/gdrive/MyDrive/trainpng2/5370.png
# FileCount = 103: Working on spectogram /content/gdrive/MyDrive/trainpng2/5364.png
# FileCount = 104: Working on spectogram /content/gdrive/MyDrive/trainpng2/64764.png
# FileCount = 105: Working on spectogram /content/gdrive/MyDrive/trainpng2/5365.png
# FileCount = 106: Working on spectogram /content/gdrive/MyDrive/trainpng2/64758.png
# FileCount = 107: Working on spectogram /content/gdrive/MyDrive/trainpng2/64767.png
# FileCount = 108: Working on spectogram /content/gdrive/MyDrive/trainpng2/64768.png
# FileCount = 109: Working on spectogram /content/gdrive/MyDrive/trainpng2/64769.png
# FileCount = 110: Working on spectogram /content/gdrive/MyDrive/trainpng2/5369.png
# FileCount = 111: Working on spectogram /content/gdrive/MyDrive/trainpng2/64763.png
# FileCount = 112: Working on spectogram /content/gdrive/MyDrive/trainpng2/64766.png
# FileCount = 113: Working on spectogram /content/gdrive/MyDrive/trainpng2/5376.png
# FileCount = 114: Working on spectogram /content/gdrive/MyDrive/trainpng2/64765.png
# FileCount = 115: Working on spectogram /content/gdrive/MyDrive/trainpng2/64775.png
# FileCount = 116: Working on spectogram /content/gdrive/MyDrive/trainpng2/64770.png
# FileCount = 117: Working on spectogram /content/gdrive/MyDrive/trainpng2/5379.png
# FileCount = 118: Working on spectogram /content/gdrive/MyDrive/trainpng2/64771.png
# FileCount = 119: Working on spectogram /content/gdrive/MyDrive/trainpng2/64772.png
# FileCount = 120: Working on spectogram /content/gdrive/MyDrive/trainpng2/64774.png
# FileCount = 121: Working on spectogram /content/gdrive/MyDrive/trainpng2/64773.png
# FileCount = 122: Working on spectogram /content/gdrive/MyDrive/trainpng2/64776.png
# FileCount = 123: Working on spectogram /content/gdrive/MyDrive/trainpng2/64777.png
# FileCount = 124: Working on spectogram /content/gdrive/MyDrive/trainpng2/64779.png
# FileCount = 125: Working on spectogram /content/gdrive/MyDrive/trainpng2/64781.png
# FileCount = 126: Working on spectogram /content/gdrive/MyDrive/trainpng2/64787.png
# FileCount = 127: Working on spectogram /content/gdrive/MyDrive/trainpng2/64788.png
# FileCount = 128: Working on spectogram /content/gdrive/MyDrive/trainpng2/64789.png
# FileCount = 129: Working on spectogram /content/gdrive/MyDrive/trainpng2/64790.png
# FileCount = 130: Working on spectogram /content/gdrive/MyDrive/trainpng2/64791.png
# FileCount = 131: Working on spectogram /content/gdrive/MyDrive/trainpng2/64778.png
# FileCount = 132: Working on spectogram /content/gdrive/MyDrive/trainpng2/64794.png
# FileCount = 133: Working on spectogram /content/gdrive/MyDrive/trainpng2/64792.png
# FileCount = 134: Working on spectogram /content/gdrive/MyDrive/trainpng2/64780.png
# FileCount = 135: Working on spectogram /content/gdrive/MyDrive/trainpng2/5354.png
# FileCount = 136: Working on spectogram /content/gdrive/MyDrive/trainpng2/5356.png
# FileCount = 137: Working on spectogram /content/gdrive/MyDrive/trainpng2/97616.png
# FileCount = 138: Working on spectogram /content/gdrive/MyDrive/trainpng2/5359.png
# FileCount = 139: Working on spectogram /content/gdrive/MyDrive/trainpng2/97622.png
# /usr/local/lib/python3.7/dist-packages/librosa/core/spectrum.py:224: UserWarning: n_fft=42336 is too small for input signal of length=35643
#   n_fft, y.shape[-1]
# FileCount = 140: Working on spectogram /content/gdrive/MyDrive/trainpng2/97623.png
# /usr/local/lib/python3.7/dist-packages/librosa/core/spectrum.py:224: UserWarning: n_fft=42336 is too small for input signal of length=30300
#   n_fft, y.shape[-1]
# FileCount = 141: Working on spectogram /content/gdrive/MyDrive/trainpng2/97624.png
# /usr/local/lib/python3.7/dist-packages/librosa/core/spectrum.py:224: UserWarning: n_fft=42336 is too small for input signal of length=33811
#   n_fft, y.shape[-1]
# FileCount = 142: Working on spectogram /content/gdrive/MyDrive/trainpng2/97625.png
# /usr/local/lib/python3.7/dist-packages/librosa/core/spectrum.py:224: UserWarning: n_fft=42336 is too small for input signal of length=28312
#   n_fft, y.shape[-1]
# FileCount = 143: Working on spectogram /content/gdrive/MyDrive/trainpng2/97626.png
# /usr/local/lib/python3.7/dist-packages/librosa/core/spectrum.py:224: UserWarning: n_fft=42336 is too small for input signal of length=30963
#   n_fft, y.shape[-1]
# FileCount = 144: Working on spectogram /content/gdrive/MyDrive/trainpng2/97627.png
# FileCount = 145: Working on spectogram /content/gdrive/MyDrive/trainpng2/97629.png
# /usr/local/lib/python3.7/dist-packages/librosa/core/spectrum.py:224: UserWarning: n_fft=42336 is too small for input signal of length=41804
#   n_fft, y.shape[-1]
# FileCount = 146: Working on spectogram /content/gdrive/MyDrive/trainpng2/97630.png
# /usr/local/lib/python3.7/dist-packages/librosa/core/spectrum.py:224: UserWarning: n_fft=42336 is too small for input signal of length=35994
#   n_fft, y.shape[-1]
# FileCount = 147: Working on spectogram /content/gdrive/MyDrive/trainpng2/97631.png
# /usr/local/lib/python3.7/dist-packages/librosa/core/spectrum.py:224: UserWarning: n_fft=42336 is too small for input signal of length=40401
#   n_fft, y.shape[-1]
# FileCount = 148: Working on spectogram /content/gdrive/MyDrive/trainpng2/97632.png
# /usr/local/lib/python3.7/dist-packages/librosa/core/spectrum.py:224: UserWarning: n_fft=42336 is too small for input signal of length=35838
#   n_fft, y.shape[-1]
# FileCount = 149: Working on spectogram /content/gdrive/MyDrive/trainpng2/97633.png
# /usr/local/lib/python3.7/dist-packages/librosa/core/spectrum.py:224: UserWarning: n_fft=42336 is too small for input signal of length=36150
#   n_fft, y.shape[-1]
# FileCount = 150: Working on spectogram /content/gdrive/MyDrive/trainpng2/97634.png
# FileCount = 151: Working on spectogram /content/gdrive/MyDrive/trainpng2/97635.png
# FileCount = 152: Working on spectogram /content/gdrive/MyDrive/trainpng2/97636.png
# FileCount = 153: Working on spectogram /content/gdrive/MyDrive/trainpng2/97637.png
# FileCount = 154: Working on spectogram /content/gdrive/MyDrive/trainpng2/97638.png
# FileCount = 155: Working on spectogram /content/gdrive/MyDrive/trainpng2/97639.png
# FileCount = 156: Working on spectogram /content/gdrive/MyDrive/trainpng2/97641.png
# FileCount = 157: Working on spectogram /content/gdrive/MyDrive/trainpng2/97642.png
# FileCount = 158: Working on spectogram /content/gdrive/MyDrive/trainpng2/97643.png
# FileCount = 159: Working on spectogram /content/gdrive/MyDrive/trainpng2/97644.png
# FileCount = 160: Working on spectogram /content/gdrive/MyDrive/trainpng2/97645.png
# FileCount = 161: Working on spectogram /content/gdrive/MyDrive/trainpng2/97646.png
# FileCount = 162: Working on spectogram /content/gdrive/MyDrive/trainpng2/97647.png
# FileCount = 163: Working on spectogram /content/gdrive/MyDrive/trainpng2/97648.png
# FileCount = 164: Working on spectogram /content/gdrive/MyDrive/trainpng2/97649.png
# FileCount = 165: Working on spectogram /content/gdrive/MyDrive/trainpng2/97650.png
# FileCount = 166: Working on spectogram /content/gdrive/MyDrive/trainpng2/97651.png
# FileCount = 167: Working on spectogram /content/gdrive/MyDrive/trainpng2/97652.png
# FileCount = 168: Working on spectogram /content/gdrive/MyDrive/trainpng2/97653.png
# FileCount = 169: Working on spectogram /content/gdrive/MyDrive/trainpng2/5366.png
# FileCount = 170: Working on spectogram /content/gdrive/MyDrive/trainpng2/97654.png
# FileCount = 171: Working on spectogram /content/gdrive/MyDrive/trainpng2/97655.png
# FileCount = 172: Working on spectogram /content/gdrive/MyDrive/trainpng2/97656.png
# FileCount = 173: Working on spectogram /content/gdrive/MyDrive/trainpng2/97657.png
# FileCount = 174: Working on spectogram /content/gdrive/MyDrive/trainpng2/324052.png
# FileCount = 175: Working on spectogram /content/gdrive/MyDrive/trainpng2/324053.png
# FileCount = 176: Working on spectogram /content/gdrive/MyDrive/trainpng2/40404.png
# FileCount = 177: Working on spectogram /content/gdrive/MyDrive/trainpng2/324055.png
# FileCount = 178: Working on spectogram /content/gdrive/MyDrive/trainpng2/40405.png
# FileCount = 179: Working on spectogram /content/gdrive/MyDrive/trainpng2/324057.png
# FileCount = 180: Working on spectogram /content/gdrive/MyDrive/trainpng2/324058.png
# FileCount = 181: Working on spectogram /content/gdrive/MyDrive/trainpng2/324059.png
# FileCount = 182: Working on spectogram /content/gdrive/MyDrive/trainpng2/324060.png
# FileCount = 183: Working on spectogram /content/gdrive/MyDrive/trainpng2/324061.png
# FileCount = 184: Working on spectogram /content/gdrive/MyDrive/trainpng2/324062.png
# FileCount = 185: Working on spectogram /content/gdrive/MyDrive/trainpng2/324063.png
# FileCount = 186: Working on spectogram /content/gdrive/MyDrive/trainpng2/40413.png
# FileCount = 187: Working on spectogram /content/gdrive/MyDrive/trainpng2/40408.png
# FileCount = 188: Working on spectogram /content/gdrive/MyDrive/trainpng2/40409.png
# FileCount = 189: Working on spectogram /content/gdrive/MyDrive/trainpng2/40410.png
# FileCount = 190: Working on spectogram /content/gdrive/MyDrive/trainpng2/40411.png
# FileCount = 191: Working on spectogram /content/gdrive/MyDrive/trainpng2/40412.png
# FileCount = 192: Working on spectogram /content/gdrive/MyDrive/trainpng2/40415.png
# FileCount = 193: Working on spectogram /content/gdrive/MyDrive/trainpng2/40414.png
# FileCount = 194: Working on spectogram /content/gdrive/MyDrive/trainpng2/40417.png
# FileCount = 195: Working on spectogram /content/gdrive/MyDrive/trainpng2/40418.png
# FileCount = 196: Working on spectogram /content/gdrive/MyDrive/trainpng2/40426.png
# FileCount = 197: Working on spectogram /content/gdrive/MyDrive/trainpng2/40419.png
# FileCount = 198: Working on spectogram /content/gdrive/MyDrive/trainpng2/40420.png
# FileCount = 199: Working on spectogram /content/gdrive/MyDrive/trainpng2/40421.png
# FileCount = 200: Working on spectogram /content/gdrive/MyDrive/trainpng2/40423.png
# FileCount = 201: Working on spectogram /content/gdrive/MyDrive/trainpng2/40424.png
# FileCount = 202: Working on spectogram /content/gdrive/MyDrive/trainpng2/40425.png
# FileCount = 203: Working on spectogram /content/gdrive/MyDrive/trainpng2/40427.png
# FileCount = 204: Working on spectogram /content/gdrive/MyDrive/trainpng2/40428.png
# FileCount = 205: Working on spectogram /content/gdrive/MyDrive/trainpng2/2547.png
# /usr/local/lib/python3.7/dist-packages/librosa/core/spectrum.py:224: UserWarning: n_fft=42336 is too small for input signal of length=28789
#   n_fft, y.shape[-1]
# FileCount = 206: Working on spectogram /content/gdrive/MyDrive/trainpng2/40429.png
# FileCount = 207: Working on spectogram /content/gdrive/MyDrive/trainpng2/40430.png
# FileCount = 208: Working on spectogram /content/gdrive/MyDrive/trainpng2/2550.png
# FileCount = 209: Working on spectogram /content/gdrive/MyDrive/trainpng2/40431.png
# FileCount = 210: Working on spectogram /content/gdrive/MyDrive/trainpng2/40432.png
# FileCount = 211: Working on spectogram /content/gdrive/MyDrive/trainpng2/40433.png
# FileCount = 212: Working on spectogram /content/gdrive/MyDrive/trainpng2/40442.png
# FileCount = 213: Working on spectogram /content/gdrive/MyDrive/trainpng2/40434.png
# FileCount = 214: Working on spectogram /content/gdrive/MyDrive/trainpng2/40435.png
# FileCount = 215: Working on spectogram /content/gdrive/MyDrive/trainpng2/40436.png
# FileCount = 216: Working on spectogram /content/gdrive/MyDrive/trainpng2/40437.png
# FileCount = 217: Working on spectogram /content/gdrive/MyDrive/trainpng2/40439.png
# FileCount = 218: Working on spectogram /content/gdrive/MyDrive/trainpng2/40440.png
# FileCount = 219: Working on spectogram /content/gdrive/MyDrive/trainpng2/40441.png
# FileCount = 220: Working on spectogram /content/gdrive/MyDrive/trainpng2/40443.png
# FileCount = 221: Working on spectogram /content/gdrive/MyDrive/trainpng2/40444.png
# FileCount = 222: Working on spectogram /content/gdrive/MyDrive/trainpng2/40445.png
# FileCount = 223: Working on spectogram /content/gdrive/MyDrive/trainpng2/40446.png
# FileCount = 224: Working on spectogram /content/gdrive/MyDrive/trainpng2/40447.png
# FileCount = 225: Working on spectogram /content/gdrive/MyDrive/trainpng2/40448.png
# FileCount = 226: Working on spectogram /content/gdrive/MyDrive/trainpng2/40449.png
# FileCount = 227: Working on spectogram /content/gdrive/MyDrive/trainpng2/40450.png
# FileCount = 228: Working on spectogram /content/gdrive/MyDrive/trainpng2/40451.png
# FileCount = 229: Working on spectogram /content/gdrive/MyDrive/trainpng2/40452.png
# FileCount = 230: Working on spectogram /content/gdrive/MyDrive/trainpng2/40453.png
# FileCount = 231: Working on spectogram /content/gdrive/MyDrive/trainpng2/40454.png
# FileCount = 232: Working on spectogram /content/gdrive/MyDrive/trainpng2/40462.png
# FileCount = 233: Working on spectogram /content/gdrive/MyDrive/trainpng2/40455.png
# FileCount = 234: Working on spectogram /content/gdrive/MyDrive/trainpng2/40456.png
# FileCount = 235: Working on spectogram /content/gdrive/MyDrive/trainpng2/40457.png
# FileCount = 236: Working on spectogram /content/gdrive/MyDrive/trainpng2/40458.png
# FileCount = 237: Working on spectogram /content/gdrive/MyDrive/trainpng2/40459.png
# FileCount = 238: Working on spectogram /content/gdrive/MyDrive/trainpng2/40468.png
# FileCount = 239: Working on spectogram /content/gdrive/MyDrive/trainpng2/40460.png
# FileCount = 240: Working on spectogram /content/gdrive/MyDrive/trainpng2/40461.png
# FileCount = 241: Working on spectogram /content/gdrive/MyDrive/trainpng2/40463.png
# FileCount = 242: Working on spectogram /content/gdrive/MyDrive/trainpng2/40473.png
# FileCount = 243: Working on spectogram /content/gdrive/MyDrive/trainpng2/40465.png
# FileCount = 244: Working on spectogram /content/gdrive/MyDrive/trainpng2/40466.png
# FileCount = 245: Working on spectogram /content/gdrive/MyDrive/trainpng2/40476.png
# /usr/local/lib/python3.7/dist-packages/librosa/core/spectrum.py:224: UserWarning: n_fft=42336 is too small for input signal of length=39760
#   n_fft, y.shape[-1]
# FileCount = 246: Working on spectogram /content/gdrive/MyDrive/trainpng2/40406.png
# FileCount = 247: Working on spectogram /content/gdrive/MyDrive/trainpng2/40470.png
# /usr/local/lib/python3.7/dist-packages/librosa/core/spectrum.py:224: UserWarning: n_fft=42336 is too small for input signal of length=39456
#   n_fft, y.shape[-1]
# FileCount = 248: Working on spectogram /content/gdrive/MyDrive/trainpng2/40471.png
# /usr/local/lib/python3.7/dist-packages/librosa/core/spectrum.py:224: UserWarning: n_fft=42336 is too small for input signal of length=40405
#   n_fft, y.shape[-1]
# FileCount = 249: Working on spectogram /content/gdrive/MyDrive/trainpng2/40472.png
# FileCount = 250: Working on spectogram /content/gdrive/MyDrive/trainpng2/40407.png
# FileCount = 251: Working on spectogram /content/gdrive/MyDrive/trainpng2/40475.png
# FileCount = 252: Working on spectogram /content/gdrive/MyDrive/trainpng2/40477.png
# FileCount = 253: Working on spectogram /content/gdrive/MyDrive/trainpng2/40478.png
# FileCount = 254: Working on spectogram /content/gdrive/MyDrive/trainpng2/40479.png
# FileCount = 255: Working on spectogram /content/gdrive/MyDrive/trainpng2/40481.png
# FileCount = 256: Working on spectogram /content/gdrive/MyDrive/trainpng2/40483.png
# FileCount = 257: Working on spectogram /content/gdrive/MyDrive/trainpng2/40484.png
# FileCount = 258: Working on spectogram /content/gdrive/MyDrive/trainpng2/40485.png
# FileCount = 259: Working on spectogram /content/gdrive/MyDrive/trainpng2/40493.png
# FileCount = 260: Working on spectogram /content/gdrive/MyDrive/trainpng2/40486.png
# FileCount = 261: Working on spectogram /content/gdrive/MyDrive/trainpng2/40488.png
# FileCount = 262: Working on spectogram /content/gdrive/MyDrive/trainpng2/40489.png
# FileCount = 263: Working on spectogram /content/gdrive/MyDrive/trainpng2/40492.png
# FileCount = 264: Working on spectogram /content/gdrive/MyDrive/trainpng2/40498.png
# FileCount = 265: Working on spectogram /content/gdrive/MyDrive/trainpng2/40499.png
# FileCount = 266: Working on spectogram /content/gdrive/MyDrive/trainpng2/40491.png
# FileCount = 267: Working on spectogram /content/gdrive/MyDrive/trainpng2/106030.png
# FileCount = 268: Working on spectogram /content/gdrive/MyDrive/trainpng2/40495.png
# FileCount = 269: Working on spectogram /content/gdrive/MyDrive/trainpng2/40497.png
# FileCount = 270: Working on spectogram /content/gdrive/MyDrive/trainpng2/40500.png
# FileCount = 271: Working on spectogram /content/gdrive/MyDrive/trainpng2/40501.png
# FileCount = 272: Working on spectogram /content/gdrive/MyDrive/trainpng2/40502.png
# FileCount = 273: Working on spectogram /content/gdrive/MyDrive/trainpng2/40503.png
# FileCount = 274: Working on spectogram /content/gdrive/MyDrive/trainpng2/40504.png
# FileCount = 275: Working on spectogram /content/gdrive/MyDrive/trainpng2/40505.png
# FileCount = 276: Working on spectogram /content/gdrive/MyDrive/trainpng2/40506.png
# FileCount = 277: Working on spectogram /content/gdrive/MyDrive/trainpng2/40507.png
# FileCount = 278: Working on spectogram /content/gdrive/MyDrive/trainpng2/40508.png
# FileCount = 279: Working on spectogram /content/gdrive/MyDrive/trainpng2/40509.png
# FileCount = 280: Working on spectogram /content/gdrive/MyDrive/trainpng2/40510.png
# FileCount = 281: Working on spectogram /content/gdrive/MyDrive/trainpng2/40511.png
# FileCount = 282: Working on spectogram /content/gdrive/MyDrive/trainpng2/40512.png
# FileCount = 283: Working on spectogram /content/gdrive/MyDrive/trainpng2/40520.png
# FileCount = 284: Working on spectogram /content/gdrive/MyDrive/trainpng2/40521.png
# FileCount = 285: Working on spectogram /content/gdrive/MyDrive/trainpng2/40513.png
# FileCount = 286: Working on spectogram /content/gdrive/MyDrive/trainpng2/40514.png
# FileCount = 287: Working on spectogram /content/gdrive/MyDrive/trainpng2/40518.png
# FileCount = 288: Working on spectogram /content/gdrive/MyDrive/trainpng2/40519.png
# FileCount = 289: Working on spectogram /content/gdrive/MyDrive/trainpng2/40522.png
# FileCount = 290: Working on spectogram /content/gdrive/MyDrive/trainpng2/40416.png
# FileCount = 291: Working on spectogram /content/gdrive/MyDrive/trainpng2/40524.png
# FileCount = 292: Working on spectogram /content/gdrive/MyDrive/trainpng2/40526.png
# FileCount = 293: Working on spectogram /content/gdrive/MyDrive/trainpng2/40527.png
# FileCount = 294: Working on spectogram /content/gdrive/MyDrive/trainpng2/40529.png
# FileCount = 295: Working on spectogram /content/gdrive/MyDrive/trainpng2/40530.png
# FileCount = 296: Working on spectogram /content/gdrive/MyDrive/trainpng2/40531.png
# FileCount = 297: Working on spectogram /content/gdrive/MyDrive/trainpng2/40528.png
# FileCount = 298: Working on spectogram /content/gdrive/MyDrive/trainpng2/202331.png
# FileCount = 299: Working on spectogram /content/gdrive/MyDrive/trainpng2/40422.png
# FileCount = 300: Working on spectogram /content/gdrive/MyDrive/trainpng2/11889.png
# FileCount = 301: Working on spectogram /content/gdrive/MyDrive/trainpng2/11890.png
# FileCount = 302: Working on spectogram /content/gdrive/MyDrive/trainpng2/11891.png
# FileCount = 303: Working on spectogram /content/gdrive/MyDrive/trainpng2/11892.png
# FileCount = 304: Working on spectogram /content/gdrive/MyDrive/trainpng2/11894.png
# FileCount = 305: Working on spectogram /content/gdrive/MyDrive/trainpng2/11895.png
# /usr/local/lib/python3.7/dist-packages/librosa/core/spectrum.py:224: UserWarning: n_fft=42336 is too small for input signal of length=34040
#   n_fft, y.shape[-1]
# FileCount = 306: Working on spectogram /content/gdrive/MyDrive/trainpng2/11896.png
# /usr/local/lib/python3.7/dist-packages/librosa/core/spectrum.py:224: UserWarning: n_fft=42336 is too small for input signal of length=34288
#   n_fft, y.shape[-1]
# FileCount = 307: Working on spectogram /content/gdrive/MyDrive/trainpng2/11897.png
# /usr/local/lib/python3.7/dist-packages/librosa/core/spectrum.py:224: UserWarning: n_fft=42336 is too small for input signal of length=32220
#   n_fft, y.shape[-1]
# FileCount = 308: Working on spectogram /content/gdrive/MyDrive/trainpng2/11898.png
# /usr/local/lib/python3.7/dist-packages/librosa/core/spectrum.py:224: UserWarning: n_fft=42336 is too small for input signal of length=38229
#   n_fft, y.shape[-1]
# FileCount = 309: Working on spectogram /content/gdrive/MyDrive/trainpng2/11899.png
# /usr/local/lib/python3.7/dist-packages/librosa/core/spectrum.py:224: UserWarning: n_fft=42336 is too small for input signal of length=35225
#   n_fft, y.shape[-1]
# FileCount = 310: Working on spectogram /content/gdrive/MyDrive/trainpng2/11900.png
# /usr/local/lib/python3.7/dist-packages/librosa/core/spectrum.py:224: UserWarning: n_fft=42336 is too small for input signal of length=34205
#   n_fft, y.shape[-1]
# FileCount = 311: Working on spectogram /content/gdrive/MyDrive/trainpng2/11901.png
# FileCount = 312: Working on spectogram /content/gdrive/MyDrive/trainpng2/11902.png
# FileCount = 313: Working on spectogram /content/gdrive/MyDrive/trainpng2/11903.png
# /usr/local/lib/python3.7/dist-packages/librosa/core/spectrum.py:224: UserWarning: n_fft=42336 is too small for input signal of length=41261
#   n_fft, y.shape[-1]
# FileCount = 314: Working on spectogram /content/gdrive/MyDrive/trainpng2/11904.png
# /usr/local/lib/python3.7/dist-packages/librosa/core/spectrum.py:224: UserWarning: n_fft=42336 is too small for input signal of length=41206
#   n_fft, y.shape[-1]
# FileCount = 315: Working on spectogram /content/gdrive/MyDrive/trainpng2/11905.png
# FileCount = 316: Working on spectogram /content/gdrive/MyDrive/trainpng2/11906.png
# FileCount = 317: Working on spectogram /content/gdrive/MyDrive/trainpng2/372378.png
# FileCount = 318: Working on spectogram /content/gdrive/MyDrive/trainpng2/372383.png
# FileCount = 319: Working on spectogram /content/gdrive/MyDrive/trainpng2/372384.png
# FileCount = 320: Working on spectogram /content/gdrive/MyDrive/trainpng2/372385.png
# FileCount = 321: Working on spectogram /content/gdrive/MyDrive/trainpng2/372386.png
# FileCount = 322: Working on spectogram /content/gdrive/MyDrive/trainpng2/372387.png
# FileCount = 323: Working on spectogram /content/gdrive/MyDrive/trainpng2/372388.png
# FileCount = 324: Working on spectogram /content/gdrive/MyDrive/trainpng2/372389.png
# FileCount = 325: Working on spectogram /content/gdrive/MyDrive/trainpng2/372390.png
# FileCount = 326: Working on spectogram /content/gdrive/MyDrive/trainpng2/372392.png
# FileCount = 327: Working on spectogram /content/gdrive/MyDrive/trainpng2/40438.png
# FileCount = 328: Working on spectogram /content/gdrive/MyDrive/trainpng2/97224.png
# FileCount = 329: Working on spectogram /content/gdrive/MyDrive/trainpng2/202245.png
# FileCount = 330: Working on spectogram /content/gdrive/MyDrive/trainpng2/3651.png
# FileCount = 331: Working on spectogram /content/gdrive/MyDrive/trainpng2/3652.png
# FileCount = 332: Working on spectogram /content/gdrive/MyDrive/trainpng2/64709.png
# FileCount = 333: Working on spectogram /content/gdrive/MyDrive/trainpng2/128818.png
# FileCount = 334: Working on spectogram /content/gdrive/MyDrive/trainpng2/128819.png
# FileCount = 335: Working on spectogram /content/gdrive/MyDrive/trainpng2/128820.png
# FileCount = 336: Working on spectogram /content/gdrive/MyDrive/trainpng2/128821.png
# FileCount = 337: Working on spectogram /content/gdrive/MyDrive/trainpng2/128822.png
# FileCount = 338: Working on spectogram /content/gdrive/MyDrive/trainpng2/128823.png
# FileCount = 339: Working on spectogram /content/gdrive/MyDrive/trainpng2/128824.png
# FileCount = 340: Working on spectogram /content/gdrive/MyDrive/trainpng2/128825.png
# FileCount = 341: Working on spectogram /content/gdrive/MyDrive/trainpng2/128826.png
# FileCount = 342: Working on spectogram /content/gdrive/MyDrive/trainpng2/128827.png
# FileCount = 343: Working on spectogram /content/gdrive/MyDrive/trainpng2/128828.png
# FileCount = 344: Working on spectogram /content/gdrive/MyDrive/trainpng2/128829.png
# FileCount = 345: Working on spectogram /content/gdrive/MyDrive/trainpng2/128830.png
# FileCount = 346: Working on spectogram /content/gdrive/MyDrive/trainpng2/128831.png
# FileCount = 347: Working on spectogram /content/gdrive/MyDrive/trainpng2/128832.png
# FileCount = 348: Working on spectogram /content/gdrive/MyDrive/trainpng2/128833.png
# FileCount = 349: Working on spectogram /content/gdrive/MyDrive/trainpng2/40464.png
# FileCount = 350: Working on spectogram /content/gdrive/MyDrive/trainpng2/128834.png
# FileCount = 351: Working on spectogram /content/gdrive/MyDrive/trainpng2/128835.png
# FileCount = 352: Working on spectogram /content/gdrive/MyDrive/trainpng2/128837.png
# FileCount = 353: Working on spectogram /content/gdrive/MyDrive/trainpng2/128838.png
# FileCount = 354: Working on spectogram /content/gdrive/MyDrive/trainpng2/128839.png
# FileCount = 355: Working on spectogram /content/gdrive/MyDrive/trainpng2/128836.png
# FileCount = 356: Working on spectogram /content/gdrive/MyDrive/trainpng2/128841.png
# FileCount = 357: Working on spectogram /content/gdrive/MyDrive/trainpng2/128842.png
# FileCount = 358: Working on spectogram /content/gdrive/MyDrive/trainpng2/128843.png
# FileCount = 359: Working on spectogram /content/gdrive/MyDrive/trainpng2/128844.png
# FileCount = 360: Working on spectogram /content/gdrive/MyDrive/trainpng2/128840.png
# FileCount = 361: Working on spectogram /content/gdrive/MyDrive/trainpng2/40467.png
# FileCount = 362: Working on spectogram /content/gdrive/MyDrive/trainpng2/40469.png
# FileCount = 363: Working on spectogram /content/gdrive/MyDrive/trainpng2/133992.png
# FileCount = 364: Working on spectogram /content/gdrive/MyDrive/trainpng2/133993.png
# FileCount = 365: Working on spectogram /content/gdrive/MyDrive/trainpng2/133994.png
# FileCount = 366: Working on spectogram /content/gdrive/MyDrive/trainpng2/133997.png
# FileCount = 367: Working on spectogram /content/gdrive/MyDrive/trainpng2/133999.png
# FileCount = 368: Working on spectogram /content/gdrive/MyDrive/trainpng2/134000.png
# FileCount = 369: Working on spectogram /content/gdrive/MyDrive/trainpng2/134003.png
# FileCount = 370: Working on spectogram /content/gdrive/MyDrive/trainpng2/134005.png
# FileCount = 371: Working on spectogram /content/gdrive/MyDrive/trainpng2/134006.png
# FileCount = 372: Working on spectogram /content/gdrive/MyDrive/trainpng2/134008.png
# FileCount = 373: Working on spectogram /content/gdrive/MyDrive/trainpng2/134009.png
# FileCount = 374: Working on spectogram /content/gdrive/MyDrive/trainpng2/134010.png
# FileCount = 375: Working on spectogram /content/gdrive/MyDrive/trainpng2/134011.png
# FileCount = 376: Working on spectogram /content/gdrive/MyDrive/trainpng2/134013.png
# FileCount = 377: Working on spectogram /content/gdrive/MyDrive/trainpng2/40480.png
# FileCount = 378: Working on spectogram /content/gdrive/MyDrive/trainpng2/63386.png
# FileCount = 379: Working on spectogram /content/gdrive/MyDrive/trainpng2/63387.png
# FileCount = 380: Working on spectogram /content/gdrive/MyDrive/trainpng2/40482.png
# FileCount = 381: Working on spectogram /content/gdrive/MyDrive/trainpng2/63388.png
# FileCount = 382: Working on spectogram /content/gdrive/MyDrive/trainpng2/63389.png
# FileCount = 383: Working on spectogram /content/gdrive/MyDrive/trainpng2/63390.png
# FileCount = 384: Working on spectogram /content/gdrive/MyDrive/trainpng2/64705.png
# FileCount = 385: Working on spectogram /content/gdrive/MyDrive/trainpng2/40487.png
# FileCount = 386: Working on spectogram /content/gdrive/MyDrive/trainpng2/97216.png
# FileCount = 387: Working on spectogram /content/gdrive/MyDrive/trainpng2/97217.png
# FileCount = 388: Working on spectogram /content/gdrive/MyDrive/trainpng2/97218.png
# FileCount = 389: Working on spectogram /content/gdrive/MyDrive/trainpng2/97219.png
# FileCount = 390: Working on spectogram /content/gdrive/MyDrive/trainpng2/97220.png
# FileCount = 391: Working on spectogram /content/gdrive/MyDrive/trainpng2/97221.png
# FileCount = 392: Working on spectogram /content/gdrive/MyDrive/trainpng2/97222.png
# FileCount = 393: Working on spectogram /content/gdrive/MyDrive/trainpng2/97223.png
# FileCount = 394: Working on spectogram /content/gdrive/MyDrive/trainpng2/64710.png
# FileCount = 395: Working on spectogram /content/gdrive/MyDrive/trainpng2/97225.png
# FileCount = 396: Working on spectogram /content/gdrive/MyDrive/trainpng2/97226.png
# FileCount = 397: Working on spectogram /content/gdrive/MyDrive/trainpng2/97227.png
# FileCount = 398: Working on spectogram /content/gdrive/MyDrive/trainpng2/97228.png
# FileCount = 399: Working on spectogram /content/gdrive/MyDrive/trainpng2/97229.png
# FileCount = 400: Working on spectogram /content/gdrive/MyDrive/trainpng2/97230.png
# FileCount = 401: Working on spectogram /content/gdrive/MyDrive/trainpng2/97231.png
# FileCount = 402: Working on spectogram /content/gdrive/MyDrive/trainpng2/97232.png
# FileCount = 403: Working on spectogram /content/gdrive/MyDrive/trainpng2/97233.png
# FileCount = 404: Working on spectogram /content/gdrive/MyDrive/trainpng2/97234.png
# FileCount = 405: Working on spectogram /content/gdrive/MyDrive/trainpng2/97235.png
# FileCount = 406: Working on spectogram /content/gdrive/MyDrive/trainpng2/97236.png
# FileCount = 407: Working on spectogram /content/gdrive/MyDrive/trainpng2/97237.png
# /usr/local/lib/python3.7/dist-packages/librosa/core/spectrum.py:224: UserWarning: n_fft=42336 is too small for input signal of length=41989
#   n_fft, y.shape[-1]
# FileCount = 408: Working on spectogram /content/gdrive/MyDrive/trainpng2/97238.png
# FileCount = 409: Working on spectogram /content/gdrive/MyDrive/trainpng2/97239.png
# /usr/local/lib/python3.7/dist-packages/librosa/core/spectrum.py:224: UserWarning: n_fft=42336 is too small for input signal of length=42302
#   n_fft, y.shape[-1]
# FileCount = 410: Working on spectogram /content/gdrive/MyDrive/trainpng2/97240.png
# FileCount = 411: Working on spectogram /content/gdrive/MyDrive/trainpng2/97241.png
# FileCount = 412: Working on spectogram /content/gdrive/MyDrive/trainpng2/40494.png
# FileCount = 413: Working on spectogram /content/gdrive/MyDrive/trainpng2/97243.png
# FileCount = 414: Working on spectogram /content/gdrive/MyDrive/trainpng2/64713.png
# FileCount = 415: Working on spectogram /content/gdrive/MyDrive/trainpng2/97245.png
# FileCount = 416: Working on spectogram /content/gdrive/MyDrive/trainpng2/97246.png
# FileCount = 417: Working on spectogram /content/gdrive/MyDrive/trainpng2/97247.png
# FileCount = 418: Working on spectogram /content/gdrive/MyDrive/trainpng2/97248.png
# FileCount = 419: Working on spectogram /content/gdrive/MyDrive/trainpng2/97249.png
# FileCount = 420: Working on spectogram /content/gdrive/MyDrive/trainpng2/97250.png
# FileCount = 421: Working on spectogram /content/gdrive/MyDrive/trainpng2/97251.png
# FileCount = 422: Working on spectogram /content/gdrive/MyDrive/trainpng2/40496.png
# FileCount = 423: Working on spectogram /content/gdrive/MyDrive/trainpng2/106031.png
# FileCount = 424: Working on spectogram /content/gdrive/MyDrive/trainpng2/268254.png
# FileCount = 425: Working on spectogram /content/gdrive/MyDrive/trainpng2/64759.png
# FileCount = 426: Working on spectogram /content/gdrive/MyDrive/trainpng2/268255.png
# FileCount = 427: Working on spectogram /content/gdrive/MyDrive/trainpng2/268256.png
# FileCount = 428: Working on spectogram /content/gdrive/MyDrive/trainpng2/268257.png
# FileCount = 429: Working on spectogram /content/gdrive/MyDrive/trainpng2/268258.png
# FileCount = 430: Working on spectogram /content/gdrive/MyDrive/trainpng2/64716.png
# FileCount = 431: Working on spectogram /content/gdrive/MyDrive/trainpng2/268260.png
# FileCount = 432: Working on spectogram /content/gdrive/MyDrive/trainpng2/268261.png
# FileCount = 433: Working on spectogram /content/gdrive/MyDrive/trainpng2/268262.png
# FileCount = 434: Working on spectogram /content/gdrive/MyDrive/trainpng2/268263.png
# FileCount = 435: Working on spectogram /content/gdrive/MyDrive/trainpng2/268265.png
# FileCount = 436: Working on spectogram /content/gdrive/MyDrive/trainpng2/268266.png
# FileCount = 437: Working on spectogram /content/gdrive/MyDrive/trainpng2/268268.png
# FileCount = 438: Working on spectogram /content/gdrive/MyDrive/trainpng2/268269.png
# FileCount = 439: Working on spectogram /content/gdrive/MyDrive/trainpng2/268270.png
# FileCount = 440: Working on spectogram /content/gdrive/MyDrive/trainpng2/64719.png
# FileCount = 441: Working on spectogram /content/gdrive/MyDrive/trainpng2/322561.png
# FileCount = 442: Working on spectogram /content/gdrive/MyDrive/trainpng2/423340.png
# FileCount = 443: Working on spectogram /content/gdrive/MyDrive/trainpng2/233484.png
# FileCount = 444: Working on spectogram /content/gdrive/MyDrive/trainpng2/233485.png
# FileCount = 445: Working on spectogram /content/gdrive/MyDrive/trainpng2/195601.png
# FileCount = 446: Working on spectogram /content/gdrive/MyDrive/trainpng2/353298.png
# FileCount = 447: Working on spectogram /content/gdrive/MyDrive/trainpng2/195603.png
# FileCount = 448: Working on spectogram /content/gdrive/MyDrive/trainpng2/195604.png
# FileCount = 449: Working on spectogram /content/gdrive/MyDrive/trainpng2/195602.png
# FileCount = 450: Working on spectogram /content/gdrive/MyDrive/trainpng2/423342.png
# FileCount = 451: Working on spectogram /content/gdrive/MyDrive/trainpng2/87064.png
# FileCount = 452: Working on spectogram /content/gdrive/MyDrive/trainpng2/63520.png
# FileCount = 453: Working on spectogram /content/gdrive/MyDrive/trainpng2/63521.png
# FileCount = 454: Working on spectogram /content/gdrive/MyDrive/trainpng2/47138.png
# FileCount = 455: Working on spectogram /content/gdrive/MyDrive/trainpng2/63523.png
# /usr/local/lib/python3.7/dist-packages/librosa/core/spectrum.py:224: UserWarning: n_fft=42336 is too small for input signal of length=33113
#   n_fft, y.shape[-1]
# FileCount = 456: Working on spectogram /content/gdrive/MyDrive/trainpng2/63524.png
# FileCount = 457: Working on spectogram /content/gdrive/MyDrive/trainpng2/378917.png
# FileCount = 458: Working on spectogram /content/gdrive/MyDrive/trainpng2/47142.png
# FileCount = 459: Working on spectogram /content/gdrive/MyDrive/trainpng2/47141.png
# FileCount = 460: Working on spectogram /content/gdrive/MyDrive/trainpng2/47140.png
# FileCount = 461: Working on spectogram /content/gdrive/MyDrive/trainpng2/63522.png
# FileCount = 462: Working on spectogram /content/gdrive/MyDrive/trainpng2/94250.png
# FileCount = 463: Working on spectogram /content/gdrive/MyDrive/trainpng2/271401.png
# FileCount = 464: Working on spectogram /content/gdrive/MyDrive/trainpng2/418860.png
# FileCount = 465: Working on spectogram /content/gdrive/MyDrive/trainpng2/34873.png
# FileCount = 466: Working on spectogram /content/gdrive/MyDrive/trainpng2/130105.png
# FileCount = 467: Working on spectogram /content/gdrive/MyDrive/trainpng2/80954.png
# FileCount = 468: Working on spectogram /content/gdrive/MyDrive/trainpng2/68669.png
# FileCount = 469: Working on spectogram /content/gdrive/MyDrive/trainpng2/326723.png
# FileCount = 470: Working on spectogram /content/gdrive/MyDrive/trainpng2/270405.png
# /usr/local/lib/python3.7/dist-packages/librosa/core/spectrum.py:224: UserWarning: n_fft=42336 is too small for input signal of length=14112
#   n_fft, y.shape[-1]
# FileCount = 471: Working on spectogram /content/gdrive/MyDrive/trainpng2/270406.png
# /usr/local/lib/python3.7/dist-packages/librosa/core/spectrum.py:224: UserWarning: n_fft=42336 is too small for input signal of length=15288
#   n_fft, y.shape[-1]
# FileCount = 472: Working on spectogram /content/gdrive/MyDrive/trainpng2/270408.png
# /usr/local/lib/python3.7/dist-packages/librosa/core/spectrum.py:224: UserWarning: n_fft=42336 is too small for input signal of length=15171
#   n_fft, y.shape[-1]
# FileCount = 473: Working on spectogram /content/gdrive/MyDrive/trainpng2/391246.png
# FileCount = 474: Working on spectogram /content/gdrive/MyDrive/trainpng2/250962.png
# FileCount = 475: Working on spectogram /content/gdrive/MyDrive/trainpng2/140371.png
# /usr/local/lib/python3.7/dist-packages/librosa/core/spectrum.py:224: UserWarning: n_fft=42336 is too small for input signal of length=21217
#   n_fft, y.shape[-1]
# FileCount = 476: Working on spectogram /content/gdrive/MyDrive/trainpng2/80979.png
# FileCount = 477: Working on spectogram /content/gdrive/MyDrive/trainpng2/80980.png
# FileCount = 478: Working on spectogram /content/gdrive/MyDrive/trainpng2/140375.png
# /usr/local/lib/python3.7/dist-packages/librosa/core/spectrum.py:224: UserWarning: n_fft=42336 is too small for input signal of length=19170
#   n_fft, y.shape[-1]
# FileCount = 479: Working on spectogram /content/gdrive/MyDrive/trainpng2/349274.png
# /usr/local/lib/python3.7/dist-packages/librosa/core/spectrum.py:224: UserWarning: n_fft=42336 is too small for input signal of length=29984
#   n_fft, y.shape[-1]
# FileCount = 480: Working on spectogram /content/gdrive/MyDrive/trainpng2/349275.png
# /usr/local/lib/python3.7/dist-packages/librosa/core/spectrum.py:224: UserWarning: n_fft=42336 is too small for input signal of length=37116
#   n_fft, y.shape[-1]
# FileCount = 481: Working on spectogram /content/gdrive/MyDrive/trainpng2/349276.png
# /usr/local/lib/python3.7/dist-packages/librosa/core/spectrum.py:224: UserWarning: n_fft=42336 is too small for input signal of length=38364
#   n_fft, y.shape[-1]
# FileCount = 482: Working on spectogram /content/gdrive/MyDrive/trainpng2/349279.png
# FileCount = 483: Working on spectogram /content/gdrive/MyDrive/trainpng2/349277.png
# /usr/local/lib/python3.7/dist-packages/librosa/core/spectrum.py:224: UserWarning: n_fft=42336 is too small for input signal of length=31727
#   n_fft, y.shape[-1]
# FileCount = 484: Working on spectogram /content/gdrive/MyDrive/trainpng2/17502.png
# FileCount = 485: Working on spectogram /content/gdrive/MyDrive/trainpng2/349280.png
# /usr/local/lib/python3.7/dist-packages/librosa/core/spectrum.py:224: UserWarning: n_fft=42336 is too small for input signal of length=33162
#   n_fft, y.shape[-1]
# FileCount = 486: Working on spectogram /content/gdrive/MyDrive/trainpng2/6243.png
# FileCount = 487: Working on spectogram /content/gdrive/MyDrive/trainpng2/349281.png
# /usr/local/lib/python3.7/dist-packages/librosa/core/spectrum.py:224: UserWarning: n_fft=42336 is too small for input signal of length=40216
#   n_fft, y.shape[-1]
# FileCount = 488: Working on spectogram /content/gdrive/MyDrive/trainpng2/212066.png
# FileCount = 489: Working on spectogram /content/gdrive/MyDrive/trainpng2/349283.png
# /usr/local/lib/python3.7/dist-packages/librosa/core/spectrum.py:224: UserWarning: n_fft=42336 is too small for input signal of length=37572
#   n_fft, y.shape[-1]
# FileCount = 490: Working on spectogram /content/gdrive/MyDrive/trainpng2/232549.png
# FileCount = 491: Working on spectogram /content/gdrive/MyDrive/trainpng2/232552.png
# FileCount = 492: Working on spectogram /content/gdrive/MyDrive/trainpng2/349282.png
# /usr/local/lib/python3.7/dist-packages/librosa/core/spectrum.py:224: UserWarning: n_fft=42336 is too small for input signal of length=37560
#   n_fft, y.shape[-1]
# ...
# FileCount = 2382: Working on spectogram /content/gdrive/MyDrive/trainpng2/93964.png
# FileCount = 2383: Working on spectogram /content/gdrive/MyDrive/trainpng2/89887.png
# /usr/local/lib/python3.7/dist-packages/librosa/core/spectrum.py:224: UserWarning: n_fft=42336 is too small for input signal of length=22186
#   n_fft, y.shape[-1]
# FileCount = 2384: Working on spectogram /content/gdrive/MyDrive/trainpng2/89888.png
# FileCount = 2385: Working on spectogram /content/gdrive/MyDrive/trainpng2/89889.png
# /usr/local/lib/python3.7/dist-packages/librosa/core/spectrum.py:224: UserWarning: n_fft=42336 is too small for input signal of length=28439
#   n_fft, y.shape[-1]
# FileCount = 2386: Working on spectogram /content/gdrive/MyDrive/trainpng2/89890.png
# FileCount = 2387: Working on spectogram /content/gdrive/MyDrive/trainpng2/89891.png
# /usr/local/lib/python3.7/dist-packages/librosa/core/spectrum.py:224: UserWarning: n_fft=42336 is too small for input signal of length=17764
#   n_fft, y.shape[-1]
# FileCount = 2388: Working on spectogram /content/gdrive/MyDrive/trainpng2/219940.png
# FileCount = 2389: Working on spectogram /content/gdrive/MyDrive/trainpng2/89894.png
# FileCount = 2390: Working on spectogram /content/gdrive/MyDrive/trainpng2/89895.png
# FileCount = 2391: Working on spectogram /content/gdrive/MyDrive/trainpng2/89900.png
# FileCount = 2392: Working on spectogram /content/gdrive/MyDrive/trainpng2/89901.png
# FileCount = 2393: Working on spectogram /content/gdrive/MyDrive/trainpng2/89902.png
# FileCount = 2394: Working on spectogram /content/gdrive/MyDrive/trainpng2/89903.png
# /usr/local/lib/python3.7/dist-packages/librosa/core/spectrum.py:224: UserWarning: n_fft=42336 is too small for input signal of length=27983
#   n_fft, y.shape[-1]
# FileCount = 2395: Working on spectogram /content/gdrive/MyDrive/trainpng2/89904.png
# /usr/local/lib/python3.7/dist-packages/librosa/core/spectrum.py:224: UserWarning: n_fft=42336 is too small for input signal of length=37864
#   n_fft, y.shape[-1]
# FileCount = 2396: Working on spectogram /content/gdrive/MyDrive/trainpng2/89905.png
# /usr/local/lib/python3.7/dist-packages/librosa/core/spectrum.py:224: UserWarning: n_fft=42336 is too small for input signal of length=26947
#   n_fft, y.shape[-1]
# FileCount = 2397: Working on spectogram /content/gdrive/MyDrive/trainpng2/362310.png
# FileCount = 2398: Working on spectogram /content/gdrive/MyDrive/trainpng2/250709.png
# FileCount = 2399: Working on spectogram /content/gdrive/MyDrive/trainpng2/88917.png
# FileCount = 2400: Working on spectogram /content/gdrive/MyDrive/trainpng2/250710.png
# FileCount = 2401: Working on spectogram /content/gdrive/MyDrive/trainpng2/88920.png
# /usr/local/lib/python3.7/dist-packages/librosa/core/spectrum.py:224: UserWarning: n_fft=42336 is too small for input signal of length=36688
#   n_fft, y.shape[-1]
# FileCount = 2402: Working on spectogram /content/gdrive/MyDrive/trainpng2/88921.png
# FileCount = 2403: Working on spectogram /content/gdrive/MyDrive/trainpng2/88922.png
# FileCount = 2404: Working on spectogram /content/gdrive/MyDrive/trainpng2/88923.png
# /usr/local/lib/python3.7/dist-packages/librosa/core/spectrum.py:224: UserWarning: n_fft=42336 is too small for input signal of length=15916
#   n_fft, y.shape[-1]
# FileCount = 2405: Working on spectogram /content/gdrive/MyDrive/trainpng2/88924.png
# FileCount = 2406: Working on spectogram /content/gdrive/MyDrive/trainpng2/88925.png
# FileCount = 2407: Working on spectogram /content/gdrive/MyDrive/trainpng2/88926.png
# FileCount = 2408: Working on spectogram /content/gdrive/MyDrive/trainpng2/88927.png
# FileCount = 2409: Working on spectogram /content/gdrive/MyDrive/trainpng2/88928.png
# /usr/local/lib/python3.7/dist-packages/librosa/core/spectrum.py:224: UserWarning: n_fft=42336 is too small for input signal of length=20717
#   n_fft, y.shape[-1]
# FileCount = 2410: Working on spectogram /content/gdrive/MyDrive/trainpng2/88931.png
# /usr/local/lib/python3.7/dist-packages/librosa/core/spectrum.py:224: UserWarning: n_fft=42336 is too small for input signal of length=24457
#   n_fft, y.shape[-1]
# FileCount = 2411: Working on spectogram /content/gdrive/MyDrive/trainpng2/88932.png
# /usr/local/lib/python3.7/dist-packages/librosa/core/spectrum.py:224: UserWarning: n_fft=42336 is too small for input signal of length=36219
#   n_fft, y.shape[-1]
# FileCount = 2412: Working on spectogram /content/gdrive/MyDrive/trainpng2/88933.png
# FileCount = 2413: Working on spectogram /content/gdrive/MyDrive/trainpng2/95078.png
# FileCount = 2414: Working on spectogram /content/gdrive/MyDrive/trainpng2/88935.png
# /usr/local/lib/python3.7/dist-packages/librosa/core/spectrum.py:224: UserWarning: n_fft=42336 is too small for input signal of length=33561
#   n_fft, y.shape[-1]
# FileCount = 2415: Working on spectogram /content/gdrive/MyDrive/trainpng2/88936.png
# FileCount = 2416: Working on spectogram /content/gdrive/MyDrive/trainpng2/88937.png
# FileCount = 2417: Working on spectogram /content/gdrive/MyDrive/trainpng2/88941.png
# /usr/local/lib/python3.7/dist-packages/librosa/core/spectrum.py:224: UserWarning: n_fft=42336 is too small for input signal of length=35750
#   n_fft, y.shape[-1]
# FileCount = 2418: Working on spectogram /content/gdrive/MyDrive/trainpng2/88942.png
# /usr/local/lib/python3.7/dist-packages/librosa/core/spectrum.py:224: UserWarning: n_fft=42336 is too small for input signal of length=29692
#   n_fft, y.shape[-1]
# FileCount = 2419: Working on spectogram /content/gdrive/MyDrive/trainpng2/88944.png
# /usr/local/lib/python3.7/dist-packages/librosa/core/spectrum.py:224: UserWarning: n_fft=42336 is too small for input signal of length=41381
#   n_fft, y.shape[-1]
# FileCount = 2420: Working on spectogram /content/gdrive/MyDrive/trainpng2/88945.png
# FileCount = 2421: Working on spectogram /content/gdrive/MyDrive/trainpng2/88948.png
# FileCount = 2422: Working on spectogram /content/gdrive/MyDrive/trainpng2/88949.png
# /usr/local/lib/python3.7/dist-packages/librosa/core/spectrum.py:224: UserWarning: n_fft=42336 is too small for input signal of length=37623
#   n_fft, y.shape[-1]
# FileCount = 2423: Working on spectogram /content/gdrive/MyDrive/trainpng2/88950.png
# FileCount = 2424: Working on spectogram /content/gdrive/MyDrive/trainpng2/204685.png
# FileCount = 2425: Working on spectogram /content/gdrive/MyDrive/trainpng2/204686.png
# FileCount = 2426: Working on spectogram /content/gdrive/MyDrive/trainpng2/204687.png
# FileCount = 2427: Working on spectogram /content/gdrive/MyDrive/trainpng2/204688.png
# /usr/local/lib/python3.7/dist-packages/librosa/core/spectrum.py:224: UserWarning: n_fft=42336 is too small for input signal of length=35840
#   n_fft, y.shape[-1]
# FileCount = 2428: Working on spectogram /content/gdrive/MyDrive/trainpng2/204692.png
# FileCount = 2429: Working on spectogram /content/gdrive/MyDrive/trainpng2/42900.png
# FileCount = 2430: Working on spectogram /content/gdrive/MyDrive/trainpng2/42902.png
# FileCount = 2431: Working on spectogram /content/gdrive/MyDrive/trainpng2/42901.png
# FileCount = 2432: Working on spectogram /content/gdrive/MyDrive/trainpng2/204694.png
# /usr/local/lib/python3.7/dist-packages/librosa/core/spectrum.py:224: UserWarning: n_fft=42336 is too small for input signal of length=19456
#   n_fft, y.shape[-1]
# FileCount = 2433: Working on spectogram /content/gdrive/MyDrive/trainpng2/204695.png
# /usr/local/lib/python3.7/dist-packages/librosa/core/spectrum.py:224: UserWarning: n_fft=42336 is too small for input signal of length=15232
#   n_fft, y.shape[-1]
# FileCount = 2434: Working on spectogram /content/gdrive/MyDrive/trainpng2/42904.png
# FileCount = 2435: Working on spectogram /content/gdrive/MyDrive/trainpng2/204697.png
# /usr/local/lib/python3.7/dist-packages/librosa/core/spectrum.py:224: UserWarning: n_fft=42336 is too small for input signal of length=22784
#   n_fft, y.shape[-1]
# FileCount = 2436: Working on spectogram /content/gdrive/MyDrive/trainpng2/42906.png
# FileCount = 2437: Working on spectogram /content/gdrive/MyDrive/trainpng2/42907.png
# FileCount = 2438: Working on spectogram /content/gdrive/MyDrive/trainpng2/42903.png
# FileCount = 2439: Working on spectogram /content/gdrive/MyDrive/trainpng2/126877.png
# FileCount = 2440: Working on spectogram /content/gdrive/MyDrive/trainpng2/204698.png
# /usr/local/lib/python3.7/dist-packages/librosa/core/spectrum.py:224: UserWarning: n_fft=42336 is too small for input signal of length=14944
#   n_fft, y.shape[-1]
# FileCount = 2441: Working on spectogram /content/gdrive/MyDrive/trainpng2/204699.png
# /usr/local/lib/python3.7/dist-packages/librosa/core/spectrum.py:224: UserWarning: n_fft=42336 is too small for input signal of length=20096
#   n_fft, y.shape[-1]
# FileCount = 2442: Working on spectogram /content/gdrive/MyDrive/trainpng2/156578.png
# FileCount = 2443: Working on spectogram /content/gdrive/MyDrive/trainpng2/126878.png
# FileCount = 2444: Working on spectogram /content/gdrive/MyDrive/trainpng2/348106.png
# FileCount = 2445: Working on spectogram /content/gdrive/MyDrive/trainpng2/66519.png
# FileCount = 2446: Working on spectogram /content/gdrive/MyDrive/trainpng2/66520.png
# FileCount = 2447: Working on spectogram /content/gdrive/MyDrive/trainpng2/256993.png
# FileCount = 2448: Working on spectogram /content/gdrive/MyDrive/trainpng2/383988.png
# /usr/local/lib/python3.7/dist-packages/librosa/core/spectrum.py:224: UserWarning: n_fft=42336 is too small for input signal of length=20887
#   n_fft, y.shape[-1]
# FileCount = 2449: Working on spectogram /content/gdrive/MyDrive/trainpng2/160759.png
# FileCount = 2450: Working on spectogram /content/gdrive/MyDrive/trainpng2/344067.png
# /usr/local/lib/python3.7/dist-packages/librosa/core/spectrum.py:224: UserWarning: n_fft=42336 is too small for input signal of length=21148
#   n_fft, y.shape[-1]
# FileCount = 2451: Working on spectogram /content/gdrive/MyDrive/trainpng2/125956.png
# FileCount = 2452: Working on spectogram /content/gdrive/MyDrive/trainpng2/381963.png
# FileCount = 2453: Working on spectogram /content/gdrive/MyDrive/trainpng2/69649.png
# FileCount = 2454: Working on spectogram /content/gdrive/MyDrive/trainpng2/49177.png
# /usr/local/lib/python3.7/dist-packages/librosa/core/spectrum.py:224: UserWarning: n_fft=42336 is too small for input signal of length=23145
#   n_fft, y.shape[-1]
# FileCount = 2455: Working on spectogram /content/gdrive/MyDrive/trainpng2/176159.png
# FileCount = 2456: Working on spectogram /content/gdrive/MyDrive/trainpng2/402464.png
# FileCount = 2457: Working on spectogram /content/gdrive/MyDrive/trainpng2/402465.png
# FileCount = 2458: Working on spectogram /content/gdrive/MyDrive/trainpng2/151589.png
# FileCount = 2459: Working on spectogram /content/gdrive/MyDrive/trainpng2/151590.png
# FileCount = 2460: Working on spectogram /content/gdrive/MyDrive/trainpng2/151591.png
# FileCount = 2461: Working on spectogram /content/gdrive/MyDrive/trainpng2/346152.png
# FileCount = 2462: Working on spectogram /content/gdrive/MyDrive/trainpng2/151594.png
# FileCount = 2463: Working on spectogram /content/gdrive/MyDrive/trainpng2/346154.png
# FileCount = 2464: Working on spectogram /content/gdrive/MyDrive/trainpng2/151596.png
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-3e2074d15b2a> in <module>()
#      25     plt.axis('off')
#      26     fig2.set_size_inches(2.9, 2.98)
# ---> 27     plt.savefig(pngfile, dpi=100, bbox_inches='tight', pad_inches=0, format='png')
#      28
#      29 print('start time: ')
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/pyplot.py in savefig(*args, **kwargs)
#     721 def savefig(*args, **kwargs):
#     722     fig = gcf()
# --> 723     res = fig.savefig(*args, **kwargs)
#     724     fig.canvas.draw_idle()   # need this if 'transparent=True' to reset colors
#     725     return res
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/figure.py in savefig(self, fname, transparent, **kwargs)
#    2201             self.patch.set_visible(frameon)
#    2202
# -> 2203         self.canvas.print_figure(fname, **kwargs)
#    2204
#    2205         if frameon:
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, **kwargs)
#    2098                            else suppress())
#    2099                     with ctx:
# -> 2100                         self.figure.draw(renderer)
#    2101                     bbox_artists = kwargs.pop("bbox_extra_artists", None)
#    2102                     bbox_inches = self.figure.get_tightbbox(renderer,
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      36                 renderer.start_filter()
#      37
# ---> 38             return draw(artist, renderer, *args, **kwargs)
#      39         finally:
#      40             if artist.get_agg_filter() is not None:
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/figure.py in draw(self, renderer)
#    1734             self.patch.draw(renderer)
#    1735             mimage._draw_list_compositing_images(
# -> 1736                 renderer, self, artists, self.suppressComposite)
#    1737
#    1738             renderer.close_group('figure')
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     135     if not_composite or not has_images:
#     136         for a in artists:
# --> 137             a.draw(renderer)
#     138     else:
#     139         # Composite any adjacent images together
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      36                 renderer.start_filter()
#      37
# ---> 38             return draw(artist, renderer, *args, **kwargs)
#      39         finally:
#      40             if artist.get_agg_filter() is not None:
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/axes/_base.py in draw(self, renderer, inframe)
#    2628             renderer.stop_rasterizing()
#    2629
# -> 2630         mimage._draw_list_compositing_images(renderer, self, artists)
#    2631
#    2632         renderer.close_group('axes')
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     135     if not_composite or not has_images:
#     136         for a in artists:
# --> 137             a.draw(renderer)
#     138     else:
#     139         # Composite any adjacent images together
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      36                 renderer.start_filter()
#      37
# ---> 38             return draw(artist, renderer, *args, **kwargs)
#      39         finally:
#      40             if artist.get_agg_filter() is not None:
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/collections.py in draw(self, renderer)
#    2059
#    2060         gc = renderer.new_gc()
# -> 2061         self._set_gc_clip(gc)
#    2062         gc.set_linewidth(self.get_linewidth()[0])
#    2063
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/artist.py in _set_gc_clip(self, gc)
#     861             if self.clipbox is not None:
#     862                 gc.set_clip_rectangle(self.clipbox)
# --> 863             gc.set_clip_path(self._clippath)
#     864         else:
#     865             gc.set_clip_rectangle(None)
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/backend_bases.py in set_clip_path(self, path)
#     907         path : `~matplotlib.transforms.TransformedPath` or None
#     908         """
# --> 909         cbook._check_isinstance((transforms.TransformedPath, None), path=path)
#     910         self._clippath = path
#     911
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/cbook/__init__.py in _check_isinstance(_types, **kwargs)
#    2117     names = [*map(type_name, types)]
#    2118     if none_allowed:
# -> 2119         types = (*types, type(None))
#    2120         names.append("None")
#    2121     for k, v in kwargs.items():
#
# KeyboardInterrupt:

# %%
! ls /content/gdrive/MyDrive/trainpng2 | wc
! ls /content/gdrive/MyDrive/dumptrainpng | wc

# %%
! pwd
! mv /content/gdrive/MyDrive/trainpng2/* /content/gdrive/MyDrive/dumptrainpng/
! ls /content/gdrive/MyDrive/trainpng2 | wc
! ls /content/gdrive/MyDrive/dumptrainpng | wc

# %%
filect = 0 
print('Working on subset df_2 = dftrain.iloc[4001:8000,:]')
for i in df_2.itertuples():
    filect = filect+1
    file = i[5]
    pngfile = i[6]
    print('FileCount = '+str(filect)+': Working on spectogram '+pngfile)
    signal, sr = librosa.load(file, sr=None)
    # my parameters
    hop_length = 11025 # in num. of samples
    n_fft = 42336 # window in num. of samples
    hop_length_duration = float(hop_length)/sr
    n_fft_duration = float(n_fft)/sr
    # Mel filter banks
    filter_banks = librosa.filters.mel(n_fft=n_fft, sr=sr, n_mels=64)
    stft = librosa.stft(signal, n_fft=n_fft, hop_length=hop_length)
    # This will yield 96-length spectrograms
    spectrogram = np.abs(stft)
    # converted to 64 bin log-scaled Mel spectrogram,
    melspec = librosa.feature.melspectrogram(y=signal, sr=sr, S=spectrogram, n_fft=n_fft, hop_length=hop_length, win_length=None, window='hann', center=True, pad_mode='reflect', n_mels=64)
    log_mel_spectrogram = librosa.power_to_db(melspec, ref=np.max)
    #plt.figure(figsize=(2.24, 2.24))
    fig = librosa.display.specshow(log_mel_spectrogram, hop_length=hop_length)
    fig2 = plt.gcf()
    plt.axis('off')
    fig2.set_size_inches(2.9, 2.98)
    plt.savefig(pngfile, dpi=100, bbox_inches='tight', pad_inches=0, format='png')

print('start time: ')
print(startime)
print(time.ctime())

# %%
! ls /content/gdrive/MyDrive/trainpng2 | wc
! ls /content/gdrive/MyDrive/dumptrainpng | wc

# %%
! pwd
! mv /content/gdrive/MyDrive/trainpng2/* /content/gdrive/MyDrive/dumptrainpng/
! ls /content/gdrive/MyDrive/trainpng2 | wc
! ls /content/gdrive/MyDrive/dumptrainpng | wc

# %%
filect = 0 
print('Working on subset df_3 = dftrain.iloc[8001:12000,:]')
for i in df_3.itertuples():
    filect = filect+1
    file = i[5]
    pngfile = i[6]
    print('FileCount = '+str(filect)+': Working on spectogram '+pngfile)
    signal, sr = librosa.load(file, sr=None)
    # my parameters
    hop_length = 11025 # in num. of samples
    n_fft = 42336 # window in num. of samples
    hop_length_duration = float(hop_length)/sr
    n_fft_duration = float(n_fft)/sr
    # Mel filter banks
    filter_banks = librosa.filters.mel(n_fft=n_fft, sr=sr, n_mels=64)
    stft = librosa.stft(signal, n_fft=n_fft, hop_length=hop_length)
    # This will yield 96-length spectrograms
    spectrogram = np.abs(stft)
    # converted to 64 bin log-scaled Mel spectrogram,
    melspec = librosa.feature.melspectrogram(y=signal, sr=sr, S=spectrogram, n_fft=n_fft, hop_length=hop_length, win_length=None, window='hann', center=True, pad_mode='reflect', n_mels=64)
    log_mel_spectrogram = librosa.power_to_db(melspec, ref=np.max)
    #plt.figure(figsize=(2.24, 2.24))
    fig = librosa.display.specshow(log_mel_spectrogram, hop_length=hop_length)
    fig2 = plt.gcf()
    plt.axis('off')
    fig2.set_size_inches(2.9, 2.98)
    plt.savefig(pngfile, dpi=100, bbox_inches='tight', pad_inches=0, format='png')

print('start time: ')
print(startime)
print(time.ctime())

# %%
! ls /content/gdrive/MyDrive/trainpng2 | wc
! ls /content/gdrive/MyDrive/dumptrainpng | wc

# %%
! pwd
! mv /content/gdrive/MyDrive/trainpng2/* /content/gdrive/MyDrive/dumptrainpng/
! ls /content/gdrive/MyDrive/trainpng2 | wc
! ls /content/gdrive/MyDrive/dumptrainpng | wc

# %%
filect = 0 
print('Working on subset df_4 = dftrain.iloc[12001:16000,:]')
for i in df_4.itertuples():
    filect = filect+1
    file = i[5]
    pngfile = i[6]
    print('FileCount = '+str(filect)+': Working on spectogram '+pngfile)
    signal, sr = librosa.load(file, sr=None)
    # my parameters
    hop_length = 11025 # in num. of samples
    n_fft = 42336 # window in num. of samples
    hop_length_duration = float(hop_length)/sr
    n_fft_duration = float(n_fft)/sr
    # Mel filter banks
    filter_banks = librosa.filters.mel(n_fft=n_fft, sr=sr, n_mels=64)
    stft = librosa.stft(signal, n_fft=n_fft, hop_length=hop_length)
    # This will yield 96-length spectrograms
    spectrogram = np.abs(stft)
    # converted to 64 bin log-scaled Mel spectrogram,
    melspec = librosa.feature.melspectrogram(y=signal, sr=sr, S=spectrogram, n_fft=n_fft, hop_length=hop_length, win_length=None, window='hann', center=True, pad_mode='reflect', n_mels=64)
    log_mel_spectrogram = librosa.power_to_db(melspec, ref=np.max)
    #plt.figure(figsize=(2.24, 2.24))
    fig = librosa.display.specshow(log_mel_spectrogram, hop_length=hop_length)
    fig2 = plt.gcf()
    plt.axis('off')
    fig2.set_size_inches(2.9, 2.98)
    plt.savefig(pngfile, dpi=100, bbox_inches='tight', pad_inches=0, format='png')

print('start time: ')
print(startime)
print(time.ctime())

# %%
! ls /content/gdrive/MyDrive/trainpng2 | wc
! ls /content/gdrive/MyDrive/dumptrainpng | wc

# %%
! pwd
! mv /content/gdrive/MyDrive/trainpng2/* /content/gdrive/MyDrive/dumptrainpng/
! ls /content/gdrive/MyDrive/trainpng2 | wc
! ls /content/gdrive/MyDrive/dumptrainpng | wc

# %%
filect = 0 
print('Working on subset df_5 = dftrain.iloc[16001:20000,:]')
for i in df_5.itertuples():
    filect = filect+1
    file = i[5]
    pngfile = i[6]
    print('FileCount = '+str(filect)+': Working on spectogram '+pngfile)
    signal, sr = librosa.load(file, sr=None)
    # my parameters
    hop_length = 11025 # in num. of samples
    n_fft = 42336 # window in num. of samples
    hop_length_duration = float(hop_length)/sr
    n_fft_duration = float(n_fft)/sr
    # Mel filter banks
    filter_banks = librosa.filters.mel(n_fft=n_fft, sr=sr, n_mels=64)
    stft = librosa.stft(signal, n_fft=n_fft, hop_length=hop_length)
    # This will yield 96-length spectrograms
    spectrogram = np.abs(stft)
    # converted to 64 bin log-scaled Mel spectrogram,
    melspec = librosa.feature.melspectrogram(y=signal, sr=sr, S=spectrogram, n_fft=n_fft, hop_length=hop_length, win_length=None, window='hann', center=True, pad_mode='reflect', n_mels=64)
    log_mel_spectrogram = librosa.power_to_db(melspec, ref=np.max)
    #plt.figure(figsize=(2.24, 2.24))
    fig = librosa.display.specshow(log_mel_spectrogram, hop_length=hop_length)
    fig2 = plt.gcf()
    plt.axis('off')
    fig2.set_size_inches(2.9, 2.98)
    plt.savefig(pngfile, dpi=100, bbox_inches='tight', pad_inches=0, format='png')

print('start time: ')
print(startime)
print(time.ctime())

# %%
! ls /content/gdrive/MyDrive/trainpng2 | wc
! ls /content/gdrive/MyDrive/dumptrainpng | wc

# %%
! pwd
! mv /content/gdrive/MyDrive/trainpng2/* /content/gdrive/MyDrive/dumptrainpng/
! ls /content/gdrive/MyDrive/trainpng2 | wc
! ls /content/gdrive/MyDrive/dumptrainpng | wc

# %%
filect = 0 
print('Working on subset df_6 = dftrain.iloc[20001:24000,:]')
for i in df_6.itertuples():
    filect = filect+1
    file = i[5]
    pngfile = i[6]
    print('FileCount = '+str(filect)+': Working on spectogram '+pngfile)
    signal, sr = librosa.load(file, sr=None)
    # my parameters
    hop_length = 11025 # in num. of samples
    n_fft = 42336 # window in num. of samples
    hop_length_duration = float(hop_length)/sr
    n_fft_duration = float(n_fft)/sr
    # Mel filter banks
    filter_banks = librosa.filters.mel(n_fft=n_fft, sr=sr, n_mels=64)
    stft = librosa.stft(signal, n_fft=n_fft, hop_length=hop_length)
    # This will yield 96-length spectrograms
    spectrogram = np.abs(stft)
    # converted to 64 bin log-scaled Mel spectrogram,
    melspec = librosa.feature.melspectrogram(y=signal, sr=sr, S=spectrogram, n_fft=n_fft, hop_length=hop_length, win_length=None, window='hann', center=True, pad_mode='reflect', n_mels=64)
    log_mel_spectrogram = librosa.power_to_db(melspec, ref=np.max)
    #plt.figure(figsize=(2.24, 2.24))
    fig = librosa.display.specshow(log_mel_spectrogram, hop_length=hop_length)
    fig2 = plt.gcf()
    plt.axis('off')
    fig2.set_size_inches(2.9, 2.98)
    plt.savefig(pngfile, dpi=100, bbox_inches='tight', pad_inches=0, format='png')

print('start time: ')
print(startime)
print(time.ctime())

# %%
! ls /content/gdrive/MyDrive/trainpng2 | wc
! ls /content/gdrive/MyDrive/dumptrainpng | wc

# %%
! pwd
! mv /content/gdrive/MyDrive/trainpng2/* /content/gdrive/MyDrive/dumptrainpng/
! ls /content/gdrive/MyDrive/trainpng2 | wc
! ls /content/gdrive/MyDrive/dumptrainpng | wc

# %%
filect = 0 
print('Working on subset df_7 = dftrain.iloc[24001:28000,:] ')
for i in df_7.itertuples():
    filect = filect+1
    file = i[5]
    pngfile = i[6]
    print('FileCount = '+str(filect)+': Working on spectogram '+pngfile)
    signal, sr = librosa.load(file, sr=None)
    # my parameters
    hop_length = 11025 # in num. of samples
    n_fft = 42336 # window in num. of samples
    hop_length_duration = float(hop_length)/sr
    n_fft_duration = float(n_fft)/sr
    # Mel filter banks
    filter_banks = librosa.filters.mel(n_fft=n_fft, sr=sr, n_mels=64)
    stft = librosa.stft(signal, n_fft=n_fft, hop_length=hop_length)
    # This will yield 96-length spectrograms
    spectrogram = np.abs(stft)
    # converted to 64 bin log-scaled Mel spectrogram,
    melspec = librosa.feature.melspectrogram(y=signal, sr=sr, S=spectrogram, n_fft=n_fft, hop_length=hop_length, win_length=None, window='hann', center=True, pad_mode='reflect', n_mels=64)
    log_mel_spectrogram = librosa.power_to_db(melspec, ref=np.max)
    #plt.figure(figsize=(2.24, 2.24))
    fig = librosa.display.specshow(log_mel_spectrogram, hop_length=hop_length)
    fig2 = plt.gcf()
    plt.axis('off')
    fig2.set_size_inches(2.9, 2.98)
    plt.savefig(pngfile, dpi=100, bbox_inches='tight', pad_inches=0, format='png')

print('start time: ')
print(startime)
print(time.ctime())

# %%
! ls /content/gdrive/MyDrive/trainpng2 | wc
! ls /content/gdrive/MyDrive/dumptrainpng | wc

# %%
! pwd
! mv /content/gdrive/MyDrive/trainpng2/* /content/gdrive/MyDrive/dumptrainpng/
! ls /content/gdrive/MyDrive/trainpng2 | wc
! ls /content/gdrive/MyDrive/dumptrainpng | wc

# %%
filect = 0 
print('Working on subset df_8 = dftrain.iloc[28001:32000,:] ')
for i in df_8.itertuples():
    filect = filect+1
    file = i[5]
    pngfile = i[6]
    print('FileCount = '+str(filect)+': Working on spectogram '+pngfile)
    signal, sr = librosa.load(file, sr=None)
    # my parameters
    hop_length = 11025 # in num. of samples
    n_fft = 42336 # window in num. of samples
    hop_length_duration = float(hop_length)/sr
    n_fft_duration = float(n_fft)/sr
    # Mel filter banks
    filter_banks = librosa.filters.mel(n_fft=n_fft, sr=sr, n_mels=64)
    stft = librosa.stft(signal, n_fft=n_fft, hop_length=hop_length)
    # This will yield 96-length spectrograms
    spectrogram = np.abs(stft)
    # converted to 64 bin log-scaled Mel spectrogram,
    melspec = librosa.feature.melspectrogram(y=signal, sr=sr, S=spectrogram, n_fft=n_fft, hop_length=hop_length, win_length=None, window='hann', center=True, pad_mode='reflect', n_mels=64)
    log_mel_spectrogram = librosa.power_to_db(melspec, ref=np.max)
    #plt.figure(figsize=(2.24, 2.24))
    fig = librosa.display.specshow(log_mel_spectrogram, hop_length=hop_length)
    fig2 = plt.gcf()
    plt.axis('off')
    fig2.set_size_inches(2.9, 2.98)
    plt.savefig(pngfile, dpi=100, bbox_inches='tight', pad_inches=0, format='png')

print('start time: ')
print(startime)
print(time.ctime())

# %%
! ls /content/gdrive/MyDrive/trainpng2 | wc
! ls /content/gdrive/MyDrive/dumptrainpng | wc

# %%
! pwd
! mv /content/gdrive/MyDrive/trainpng2/* /content/gdrive/MyDrive/dumptrainpng/
! ls /content/gdrive/MyDrive/trainpng2 | wc
! ls /content/gdrive/MyDrive/dumptrainpng | wc

# %%
filect = 0 
print('Working on subset df_9 = dftrain.iloc[32001:36000,:]')
for i in df_9.itertuples():
    filect = filect+1
    file = i[5]
    pngfile = i[6]
    print('FileCount = '+str(filect)+': Working on spectogram '+pngfile)
    signal, sr = librosa.load(file, sr=None)
    # my parameters
    hop_length = 11025 # in num. of samples
    n_fft = 42336 # window in num. of samples
    hop_length_duration = float(hop_length)/sr
    n_fft_duration = float(n_fft)/sr
    # Mel filter banks
    filter_banks = librosa.filters.mel(n_fft=n_fft, sr=sr, n_mels=64)
    stft = librosa.stft(signal, n_fft=n_fft, hop_length=hop_length)
    # This will yield 96-length spectrograms
    spectrogram = np.abs(stft)
    # converted to 64 bin log-scaled Mel spectrogram,
    melspec = librosa.feature.melspectrogram(y=signal, sr=sr, S=spectrogram, n_fft=n_fft, hop_length=hop_length, win_length=None, window='hann', center=True, pad_mode='reflect', n_mels=64)
    log_mel_spectrogram = librosa.power_to_db(melspec, ref=np.max)
    #plt.figure(figsize=(2.24, 2.24))
    fig = librosa.display.specshow(log_mel_spectrogram, hop_length=hop_length)
    fig2 = plt.gcf()
    plt.axis('off')
    fig2.set_size_inches(2.9, 2.98)
    plt.savefig(pngfile, dpi=100, bbox_inches='tight', pad_inches=0, format='png')

print('start time: ')
print(startime)
print(time.ctime())

# %%
! ls /content/gdrive/MyDrive/trainpng2 | wc
! ls /content/gdrive/MyDrive/dumptrainpng | wc

# %%
! pwd
! mv /content/gdrive/MyDrive/trainpng2/* /content/gdrive/MyDrive/dumptrainpng/
! ls /content/gdrive/MyDrive/trainpng2 | wc
! ls /content/gdrive/MyDrive/dumptrainpng | wc

# %%
filect = 0 
print('Working on subset df_10 = dftrain.iloc[36001:,:] ')
for i in df_10.itertuples():
    filect = filect+1
    file = i[5]
    pngfile = i[6]
    print('FileCount = '+str(filect)+': Working on spectogram '+pngfile)
    signal, sr = librosa.load(file, sr=None)
    # my parameters
    hop_length = 11025 # in num. of samples
    n_fft = 42336 # window in num. of samples
    hop_length_duration = float(hop_length)/sr
    n_fft_duration = float(n_fft)/sr
    # Mel filter banks
    filter_banks = librosa.filters.mel(n_fft=n_fft, sr=sr, n_mels=64)
    stft = librosa.stft(signal, n_fft=n_fft, hop_length=hop_length)
    # This will yield 96-length spectrograms
    spectrogram = np.abs(stft)
    # converted to 64 bin log-scaled Mel spectrogram,
    melspec = librosa.feature.melspectrogram(y=signal, sr=sr, S=spectrogram, n_fft=n_fft, hop_length=hop_length, win_length=None, window='hann', center=True, pad_mode='reflect', n_mels=64)
    log_mel_spectrogram = librosa.power_to_db(melspec, ref=np.max)
    #plt.figure(figsize=(2.24, 2.24))
    fig = librosa.display.specshow(log_mel_spectrogram, hop_length=hop_length)
    fig2 = plt.gcf()
    plt.axis('off')
    fig2.set_size_inches(2.9, 2.98)
    plt.savefig(pngfile, dpi=100, bbox_inches='tight', pad_inches=0, format='png')

print('start time: ')
print(startime)
print(time.ctime())

# %%
! ls /content/gdrive/MyDrive/trainpng2 | wc
! ls /content/gdrive/MyDrive/dumptrainpng | wc

# %%
! pwd
! mv /content/gdrive/MyDrive/trainpng2/* /content/gdrive/MyDrive/dumptrainpng/
! ls /content/gdrive/MyDrive/trainpng2 | wc
! ls /content/gdrive/MyDrive/dumptrainpng | wc
